# %%
import pandas as pd
import numpy as np
import math as math
import statistics
import datetime
import matplotlib.pyplot as plt
import time
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from matplotlib.offsetbox import (AnnotationBbox, DrawingArea, OffsetImage,TextArea)
pd.set_option('display.max_rows',500)
pd.set_option('display.max_columns',500)
pd.set_option('max_colwidth',1000) #
pd.set_option('display.width', 150)

# %% [markdown]
# # Glossary.csv SOURCED FROM:
# https://www.nba.com/stats/help/glossary

# %%
glossaryDF = pd.read_csv('/Users/olutosinfashusi/jupyter/csv/Glossary.csv')
glossaryDict = {}
for i in range(len(glossaryDF)):
    stringInRow = glossaryDF.iloc[i].values[0]
    if stringInRow == 'Name':
        feature = glossaryDF.iloc[i-1].values[0]
        feature = feature.upper()
        glossaryDict[feature] = {}
        glossaryDict[feature]['Name'] = {}
        glossaryDict[feature]['Name'] = glossaryDF.iloc[i+1].values[0]
        glossaryDict[feature]['Definition'] = {}
        glossaryDict[feature]['Definition'] = glossaryDF.iloc[i+3].values[0]
        glossaryDict[feature]['Type'] = {}
        glossaryDict[feature]['Type'] = glossaryDF.iloc[i+5].values[0]
        glossaryDict[feature]['Contexts'] = {}
        
#FEATURES NOT IN https://www.nba.com/stats/help/glossary
glossaryDict['H/A'] = {}
glossaryDict['H/A']['Name'] = 'IS TEAM PLAYING HOME OR AWAY'
glossaryDict['H/A']['Definition'] = '0:HOME 1:AWAY'

glossaryDict['PTSA'] = {}
glossaryDict['PTSA']['Name'] = 'Points Allowed'
glossaryDict['PTSA']['Definition'] = 'The number of points allowed'

glossaryDict['PTSDELTA'] = {}
glossaryDict['PTSDELTA']['Name'] = 'Points Scored - Points Allowed'
glossaryDict['PTSDELTA']['Definition'] = 'Points Scored - Points Allowed'

glossaryDict['DAYSOFF'] = {}
glossaryDict['DAYSOFF']['Name'] = 'Number of days since last game'
glossaryDict['DAYSOFF']['Definition'] = 'Number of days since last game'

glossaryDict['W%'] = {}
glossaryDict['W%']['Name'] = 'The percentage of games played that a player or team has won'
glossaryDict['W%']['Definition'] = 'The percentage of games played that a player or team has won'

glossaryDict['L%'] = {}
glossaryDict['L%']['Name'] = 'The percentage of games played that a player or team has lost'
glossaryDict['L%']['Definition'] = 'The percentage of games played that a player or team has lost'

# %%
def convertDateColumn(df):
    locationToInsert = df.columns.get_loc('DATE')+1
    dates = pd.to_datetime(df['DATE'],format="%m/%d/%y").dt.date
    df = df.drop(columns='DATE')
    df.insert(locationToInsert,'DATE',dates)
    df = df.sort_values(by=['DATE','GAMEID']).reset_index(drop=True)
    return df
def featureEngineering(boxScoreType,df):
    if boxScoreType == 'TRADITIONAL':
        featuresToAddDict = {'OPPT':[],'PTSA':[],'2FGA':[],'2FGM':[],'2FG%':[],
                             'RESULT':[],'PTSDELTA':[],'H/A':[]}
        for i in range(len(df)):
            featuresToAddDict['OPPT'].append(df.iloc[i]['MATCH'][-3:])
            if i % 2 == 0: featuresToAddDict['PTSA'].append(df.iloc[i+1]['PTS'])
            else: featuresToAddDict['PTSA'].append(df.iloc[i-1]['PTS'])
            if df['W/L'][i] == 'L': featuresToAddDict['RESULT'].append(0)
            else: featuresToAddDict['RESULT'].append(1)
            featuresToAddDict['H/A'].append(df['MATCH'][i].count('vs'))
        df.insert(df.columns.get_loc('TEAM')+1,'OPPT',featuresToAddDict['OPPT'])
        df.insert(df.columns.get_loc('PTS')+1,'PTSA',featuresToAddDict['PTSA'])
        df.insert(df.columns.get_loc('FG%')+1,'2FGM',df['FGM'] - df['3PM'])
        df.insert(df.columns.get_loc('FG%')+1,'2FGA',df['FGA'] - df['3PA']) 
        df.insert(df.columns.get_loc('FG%')+1,'2FG%',df['2FGM']/df['2FGA'])
        df.insert(df.columns.get_loc('W/L')+1,'RESULT',featuresToAddDict['RESULT'])
        df = df.drop(columns=['W/L'])
        df.insert(df.columns.get_loc('PTSA')+1,'PTSDELTA',df['PTS']-df['PTSA'])
        df.insert(df.columns.get_loc('DATE')+1,'H/A',featuresToAddDict['H/A'])
        return df
    else:
        featuresToAddDict = {"OPPT":[],"RESULT":[],"H/A":[]}
        for i in range(len(df)):
            featuresToAddDict["OPPT"].append(df.iloc[i]['MATCH'][-3:])
            if df['W/L'][i] == 'L': featuresToAddDict["RESULT"].append(0)
            else: featuresToAddDict["RESULT"].append(1)
            featuresToAddDict["H/A"].append(df['MATCH'][i].count('vs'))
        df.insert(df.columns.get_loc('TEAM')+1,'OPPT',featuresToAddDict["OPPT"])
        df.insert(df.columns.get_loc('W/L')+1,'RESULT',featuresToAddDict["RESULT"])
        df = df.drop(columns=['W/L'])
        df.insert(df.columns.get_loc('DATE')+1,'H/A',featuresToAddDict["H/A"])
        return df
def addDaysOff(teamsDict):
    for team in list(teamsDict.keys()):
        daysOff = []
        daysOff.append(np.nan)
        for i in range(1,len(teamsDict[team]['DATE'])):
            date = teamsDict[team]['DATE'][i]
            prevDate = teamsDict[team]['DATE'][i-1] + datetime.timedelta(1)
            daysOff.append((date - prevDate).days)
        teamsDict[team]['DAYSOFF'] = daysOff
def addAdditionalFeatures(df,teamsDict):
    teams = []
    for team in list(teamsDict.keys()):
        teamDF = df[df['TEAM'] == team]
        startingIndex = len(list(df.columns))
        additionalFeatures = list(teamsDict[team].keys())[startingIndex:]
        for feature in additionalFeatures:
            teamDF = pd.concat([teamDF,
                                pd.DataFrame(teamsDict[team][feature],columns=[feature],index=teamDF.index.values)],axis=1)
        teams.append(teamDF)
    return pd.concat(teams)

def getTeamData(boxScoreType,df):
    teamsDict = {}
    features = df.columns.values
    
    if boxScoreType == 'TRADITIONAL': additionalFeatures = ['Ws','Ls','GP','W%','L%','AVGPTS','AVGPTSA']
  
    else: additionalFeatures = ['GP']
    for team in np.unique(df['TEAM']):
        teamsDict[team] = {}
    for team in np.unique(df['TEAM']):
        for feature in features:
            teamsDict[team][feature] = []
        for feature in additionalFeatures:
            teamsDict[team][feature] = []
    for i in range(len(df)):
        for feature in features:
            team = df.iloc[i]['TEAM']
            teamsDict[team][feature].append(df.iloc[i][feature])
        for feature in additionalFeatures:
            if feature == 'Ws': teamsDict[team][feature].append(teamsDict[team]['RESULT'].count(1))
            if feature == 'Ls': teamsDict[team][feature].append(teamsDict[team]['RESULT'].count(0))
            if feature == 'GP': teamsDict[team][feature].append(len(teamsDict[team]['RESULT']))
            if feature == 'W%': teamsDict[team][feature].append(teamsDict[team]['Ws'][-1]/teamsDict[team]['GP'][-1])
            if feature == 'L%': teamsDict[team][feature].append(teamsDict[team]['Ls'][-1]/teamsDict[team]['GP'][-1])
            if feature == 'AVGPTS': teamsDict[team][feature].append(np.mean(teamsDict[team]['PTS']))
            if feature == 'AVGPTSA': teamsDict[team][feature].append(np.mean(teamsDict[team]['PTSA']))
    return teamsDict

def addMovingAverageLx(featureStringsDict,teamDict,x):
    for team in list(teamsDict.keys()):
        for feature in featureStringsDict.keys():
            ma = []
            for _ in range(x): ma.append(np.nan)
            for maRange in range(0,len(teamsDict[team][feature])-x):
                ma.append(np.mean(teamsDict[team][feature][maRange:(x+maRange)]))
            teamsDict[team][featureStringsDict[feature].replace('x',str(x))] = ma
                
def addPercentMovingAverageLx(featureStringsDict,teamsDict,x):
    for team in list(teamsDict.keys()):
        for features in featureStringsDict.keys():
            ma = []
            for _ in range(x): ma.append(np.nan)
            for maRange in range(0,len(teamsDict[team][features[0]])-x):
                num = np.sum(teamsDict[team][features[0]][maRange:(x+maRange)])
                dem = np.sum(teamsDict[team][features[1]][maRange:(x+maRange)])
                ma.append(num/dem)
            teamsDict[team][featureStringsDict[features].replace('x',str(x))] = ma

# %% [markdown]
# # Traditional.csv

# %%
start_time = time.time()
traditionalDF = pd.read_csv('/Users/olutosinfashusi/jupyter/csv/fromNBADOTCOM/2023-24/byGame/Traditional.csv')
traditionalDF = convertDateColumn(traditionalDF)
traditionalDF = featureEngineering('TRADITIONAL',traditionalDF)
teamsDict = getTeamData('TRADITIONAL',traditionalDF)
print("%s seconds" % (time.time() - start_time))
# Out:
# 35.66661524772644 seconds

# %%
start_time = time.time()
features = ['PTS','PTSA','PTSDELTA','FGM','FGA','2FGA','2FGM','3PM','3PA','FTM','FTA','OREB',
            'DREB','REB','AST','STL','BLK','TOV','PF']
featureStringsDict = {}
for feature in features: featureStringsDict[feature] = feature+'LxMA'
addMovingAverageLx(featureStringsDict,teamsDict,5)
addMovingAverageLx(featureStringsDict,teamsDict,4)
addMovingAverageLx(featureStringsDict,teamsDict,3)
addMovingAverageLx(featureStringsDict,teamsDict,2)
addMovingAverageLx(featureStringsDict,teamsDict,1)


features = [('FGM','FGA'),('2FGM','2FGA'),('3PM','3PA'),('FTM','FTA'),('Ws','GP')]
featureStringsDict = {}

for feature in features:
    if feature == ('FGM','FGA'): featureStringsDict[feature] = 'FG%LxMA'
    if feature == ('2FGM','2FGA'): featureStringsDict[feature] = '2FG%LxMA'
    if feature == ('3PM','3PA'): featureStringsDict[feature] = '3P%LxMA'
    if feature == ('FTM','FTA'): featureStringsDict[feature] = 'FT%LxMA'
#     if feature == ('Ws','GP'): featureStringsDict[feature] = 'W%LxMA'
        
addPercentMovingAverageLx(featureStringsDict,teamsDict,5)
addPercentMovingAverageLx(featureStringsDict,teamsDict,4)
addPercentMovingAverageLx(featureStringsDict,teamsDict,3)
addPercentMovingAverageLx(featureStringsDict,teamsDict,2)
addPercentMovingAverageLx(featureStringsDict,teamsDict,1)

addDaysOff(teamsDict)
traditionalDF = addAdditionalFeatures(traditionalDF,teamsDict)
traditionalDF = traditionalDF.sort_values(by=['DATE','GAMEID','H/A']).reset_index(drop=True)
print("%s seconds" % (time.time() - start_time))
# Out:
# <ipython-input-3-cc31cfbcd612>:107: RuntimeWarning: invalid value encountered in scalar divide
#   ma.append(num/dem)
# 19.960511922836304 seconds

# %%
print('In rare occasion on 4/9/24 Celtics attempted 0 free throws vs Bucks [see below]')
print('Causing a warning while calculating Celtics FT%L1MA')
print('FT%L1MA feature is not used during ... ')
traditionalDF[traditionalDF['FTA'] == 0]
# Out:
# In rare occasion on 4/9/24 Celtics attempted 0 free throws vs Bucks [see below]
# Causing a warning while calculating Celtics FT%L1MA
# FT%L1MA feature is not used during ...
#      TEAM OPPT      TEAMID      MATCH    GAMEID  RESULT        DATE  H/A  SPREAD    O/U  MIN  PTS  PTSA  PTSDELTA  FGM  FGA   FG%      2FG%  2FGA  \
# 2354  BOS  MIL  1610612738  BOS @ MIL  22301148       0  2024-04-09    0     3.5  231.0  240   91   104       -13   37   93  39.8  0.487805    41
#
#       2FGM  3PM  3PA   3P%  FTM  FTA  FT%  OREB  DREB  REB  AST  STL  BLK  TOV  PF  +/-  Ws  Ls  GP       W%       L%      AVGPTS     AVGPTSA  \
# 2354    20   17   52  32.7    0    0  0.0    12    26   38   27   11    4   12   8  -13  62  17  79  0.78481  0.21519  120.443038  109.101266
#
#       PTSL5MA  PTSAL5MA  PTSDELTAL5MA  FGML5MA  FGAL5MA  2FGAL5MA  2FGML5MA  3PML5MA  3PAL5MA  FTML5MA  FTAL5MA  OREBL5MA  DREBL5MA  REBL5MA  \
# 2354    116.4     100.6          15.8     43.8     87.8      45.4      28.0     15.8     42.4     13.0     15.6       9.4      38.4     47.8
#
#       ASTL5MA  STLL5MA  BLKL5MA  TOVL5MA  PFL5MA  PTSL4MA  PTSAL4MA  PTSDELTAL4MA  FGML4MA  FGAL4MA  2FGAL4MA  2FGML4MA  3PML4MA  3PAL4MA  FTML4MA  \
# 2354     29.4      6.8      6.4     11.2    13.8    119.5    102.75         16.75     45.0    89.25      45.5      29.0     16.0    43.75     13.5
#
#       FTAL4MA  OREBL4MA  DREBL4MA  REBL4MA  ASTL4MA  STLL4MA  BLKL4MA  TOVL4MA  PFL4MA  PTSL3MA    PTSAL3MA  PTSDELTAL3MA    FGML3MA    FGAL3MA  \
# 2354     16.5      9.75     37.25     47.0     30.0     6.75     6.25    10.75    14.0    120.0  102.333333     17.666667  45.666667  89.333333
#
#        2FGAL3MA   2FGML3MA  3PML3MA    3PAL3MA    FTML3MA    FTAL3MA  OREBL3MA   DREBL3MA    REBL3MA    ASTL3MA  STLL3MA   BLKL3MA    TOVL3MA  \
# 2354  48.666667  30.666667     15.0  40.666667  13.666667  16.666667  9.333333  36.333333  45.666667  30.666667      8.0  7.333333  10.666667
#
#          PFL3MA  PTSL2MA  PTSAL2MA  PTSDELTAL2MA  FGML2MA  FGAL2MA  2FGAL2MA  2FGML2MA  3PML2MA  3PAL2MA  FTML2MA  FTAL2MA  OREBL2MA  DREBL2MA  \
# 2354  13.666667    112.5     103.5           9.0     43.5     88.0      47.0      29.5     14.0     41.0     11.5     15.5       8.5      37.0
#
#       REBL2MA  ASTL2MA  STLL2MA  BLKL2MA  TOVL2MA  PFL2MA  PTSL1MA  PTSAL1MA  PTSDELTAL1MA  FGML1MA  FGAL1MA  2FGAL1MA  2FGML1MA  3PML1MA  3PAL1MA  \
# 2354     45.5     29.5      8.5      6.0     10.5    11.5    124.0     107.0          17.0     49.0     87.0      49.0      33.0     16.0     38.0
#
#       FTML1MA  FTAL1MA  OREBL1MA  DREBL1MA  REBL1MA  ASTL1MA  STLL1MA  BLKL1MA  TOVL1MA  PFL1MA   FG%L5MA  2FG%L5MA   3P%L5MA   FT%L5MA   FG%L4MA  \
# 2354     10.0     13.0       5.0      35.0     40.0     34.0     11.0      8.0     13.0    12.0  0.498861   0.61674  0.372642  0.833333  0.504202
#
#       2FG%L4MA   3P%L4MA   FT%L4MA   FG%L3MA  2FG%L3MA   3P%L3MA  FT%L3MA   FG%L2MA  2FG%L2MA   3P%L2MA   FT%L2MA   FG%L1MA  2FG%L1MA   3P%L1MA  \
# 2354  0.637363  0.365714  0.818182  0.511194  0.630137  0.368852     0.82  0.494318   0.62766  0.341463  0.741935  0.563218  0.673469  0.421053
#
#        FT%L1MA  DAYSOFF
# 2354  0.769231      1.0

# %%
traditionalFeatures = list(traditionalDF.columns)
columnsToRemove = np.array(['TEAM','OPPT','TEAMID','MATCH','GAMEID','RESULT','DATE',
                            'SPREAD','O/U','MIN','PTS','PTSA','PTSDELTA','FGM','FGA','FG%',
                            '2FG%','2FGA','2FGM','3PM','3PA','3P%','FTM','FTA','FT%','OREB',
                            'DREB','REB','AST','STL','BLK','TOV','PF','+/-','Ws','Ls', 'GP',
                            'W%', 'L%', 'AVGPTS','AVGPTSA'])
for feature in columnsToRemove: traditionalFeatures.remove(feature)
print(traditionalFeatures)
# Out:
# ['H/A', 'PTSL5MA', 'PTSAL5MA', 'PTSDELTAL5MA', 'FGML5MA', 'FGAL5MA', '2FGAL5MA', '2FGML5MA', '3PML5MA', '3PAL5MA', 'FTML5MA', 'FTAL5MA', 'OREBL5MA', 'DREBL5MA', 'REBL5MA', 'ASTL5MA', 'STLL5MA', 'BLKL5MA', 'TOVL5MA', 'PFL5MA', 'PTSL4MA', 'PTSAL4MA', 'PTSDELTAL4MA', 'FGML4MA', 'FGAL4MA', '2FGAL4MA', '2FGML4MA', '3PML4MA', '3PAL4MA', 'FTML4MA', 'FTAL4MA', 'OREBL4MA', 'DREBL4MA', 'REBL4MA', 'ASTL4MA', 'STLL4MA', 'BLKL4MA', 'TOVL4MA', 'PFL4MA', 'PTSL3MA', 'PTSAL3MA', 'PTSDELTAL3MA', 'FGML3MA', 'FGAL3MA', '2FGAL3MA', '2FGML3MA', '3PML3MA', '3PAL3MA', 'FTML3MA', 'FTAL3MA', 'OREBL3MA', 'DREBL3MA', 'REBL3MA', 'ASTL3MA', 'STLL3MA', 'BLKL3MA', 'TOVL3MA', 'PFL3MA', 'PTSL2MA', 'PTSAL2MA', 'PTSDELTAL2MA', 'FGML2MA', 'FGAL2MA', '2FGAL2MA', '2FGML2MA', '3PML2MA', '3PAL2MA', 'FTML2MA', 'FTAL2MA', 'OREBL2MA', 'DREBL2MA', 'REBL2MA', 'ASTL2MA', 'STLL2MA', 'BLKL2MA', 'TOVL2MA', 'PFL2MA', 'PTSL1MA', 'PTSAL1MA', 'PTSDELTAL1MA', 'FGML1MA', 'FGAL1MA', '2FGAL1MA', '2FGML1MA', '3PML1MA', '3PAL1MA', 'FTML1MA', 'FTAL1MA', 'OREBL1MA', 'DREBL1MA', 'REBL1MA', 'ASTL1MA', 'STLL1MA', 'BLKL1MA', 'TOVL1MA', 'PFL1MA', 'FG%L5MA', '2FG%L5MA', '3P%L5MA', 'FT%L5MA', 'FG%L4MA', '2FG%L4MA', '3P%L4MA', 'FT%L4MA', 'FG%L3MA', '2FG%L3MA', '3P%L3MA', 'FT%L3MA', 'FG%L2MA', '2FG%L2MA', '3P%L2MA', 'FT%L2MA', 'FG%L1MA', '2FG%L1MA', '3P%L1MA', 'FT%L1MA', 'DAYSOFF']

# %% [markdown]
# # Advanced.csv

# %%
start_time = time.time()
advancedDF = pd.read_csv('/Users/olutosinfashusi/jupyter/csv/fromNBADOTCOM/2023-24/byGame/Advanced.csv')
advancedDF = convertDateColumn(advancedDF)
advancedDF = featureEngineering('ADVANCED',advancedDF)
teamsDict = getTeamData('ADVANCED',advancedDF)
print("%s seconds" % (time.time() - start_time))
# Out:
# 25.316452264785767 seconds

# %%
start_time = time.time()
features = ['OFFRTG','DEFRTG','NETRTG','AST%','AST/TO','AST RATIO','OREB%','DREB%','REB%','TOV%',
            'EFG%','TS%','PACE','PIE']
featureStringsDict = {}
for feature in features: featureStringsDict[feature] = feature+'LxMA' 
    
addMovingAverageLx(featureStringsDict,teamsDict,5)
addMovingAverageLx(featureStringsDict,teamsDict,4)
addMovingAverageLx(featureStringsDict,teamsDict,3)
addMovingAverageLx(featureStringsDict,teamsDict,2)
addMovingAverageLx(featureStringsDict,teamsDict,1)

advancedDF = addAdditionalFeatures(advancedDF,teamsDict)
advancedDF = advancedDF.sort_values(by=['DATE','GAMEID','H/A']).reset_index(drop=True)
print("%s seconds" % (time.time() - start_time))
# Out:
# 8.322057962417603 seconds

# %%
advancedFeatures = list(advancedDF.columns)
columnsToRemove = np.array(['TEAM','OPPT','TEAMID','MATCH','GAMEID','RESULT','DATE',
                            'H/A','SPREAD','O/U','MIN','OFFRTG','DEFRTG','NETRTG',
                            'AST%','AST/TO','AST RATIO','OREB%','DREB%','REB%','TOV%',
                            'EFG%','TS%','PACE','PIE','GP'])
for feature in columnsToRemove: advancedFeatures.remove(feature)
print(advancedFeatures)
# Out:
# ['OFFRTGL5MA', 'DEFRTGL5MA', 'NETRTGL5MA', 'AST%L5MA', 'AST/TOL5MA', 'AST RATIOL5MA', 'OREB%L5MA', 'DREB%L5MA', 'REB%L5MA', 'TOV%L5MA', 'EFG%L5MA', 'TS%L5MA', 'PACEL5MA', 'PIEL5MA', 'OFFRTGL4MA', 'DEFRTGL4MA', 'NETRTGL4MA', 'AST%L4MA', 'AST/TOL4MA', 'AST RATIOL4MA', 'OREB%L4MA', 'DREB%L4MA', 'REB%L4MA', 'TOV%L4MA', 'EFG%L4MA', 'TS%L4MA', 'PACEL4MA', 'PIEL4MA', 'OFFRTGL3MA', 'DEFRTGL3MA', 'NETRTGL3MA', 'AST%L3MA', 'AST/TOL3MA', 'AST RATIOL3MA', 'OREB%L3MA', 'DREB%L3MA', 'REB%L3MA', 'TOV%L3MA', 'EFG%L3MA', 'TS%L3MA', 'PACEL3MA', 'PIEL3MA', 'OFFRTGL2MA', 'DEFRTGL2MA', 'NETRTGL2MA', 'AST%L2MA', 'AST/TOL2MA', 'AST RATIOL2MA', 'OREB%L2MA', 'DREB%L2MA', 'REB%L2MA', 'TOV%L2MA', 'EFG%L2MA', 'TS%L2MA', 'PACEL2MA', 'PIEL2MA', 'OFFRTGL1MA', 'DEFRTGL1MA', 'NETRTGL1MA', 'AST%L1MA', 'AST/TOL1MA', 'AST RATIOL1MA', 'OREB%L1MA', 'DREB%L1MA', 'REB%L1MA', 'TOV%L1MA', 'EFG%L1MA', 'TS%L1MA', 'PACEL1MA', 'PIEL1MA']

# %% [markdown]
# # FourFactors.csv

# %%
start_time = time.time()
fourFactorsDF = pd.read_csv('/Users/olutosinfashusi/jupyter/csv/fromNBADOTCOM/2023-24/byGame/FourFactors.csv')
fourFactorsDF = convertDateColumn(fourFactorsDF)
fourFactorsDF = featureEngineering('FOURFACTORS',fourFactorsDF)
teamsDict = getTeamData('FOURFACTORS',fourFactorsDF)
print("%s seconds" % (time.time() - start_time))
# Out:
# 20.17856192588806 seconds

# %%
start_time = time.time()
features = ['EFG%','FTA RATE','TOV%','OREB%','OPP EFG%','OPP FTA RATE','OPP TOV%','OPP OREB%']
featureStringsDict = {}
for feature in features: featureStringsDict[feature] = feature+'LxMA' 
    
addMovingAverageLx(featureStringsDict,teamsDict,5)
addMovingAverageLx(featureStringsDict,teamsDict,4)
addMovingAverageLx(featureStringsDict,teamsDict,3)
addMovingAverageLx(featureStringsDict,teamsDict,2)
addMovingAverageLx(featureStringsDict,teamsDict,1)

fourFactorsDF = addAdditionalFeatures(fourFactorsDF,teamsDict)
fourFactorsDF = fourFactorsDF.sort_values(by=['DATE','GAMEID','H/A']).reset_index(drop=True)
print("%s seconds" % (time.time() - start_time))
# Out:
# 5.813307762145996 seconds

# %%
fourFactorsFeatures = list(fourFactorsDF.columns)
columnsToRemove = np.array(['TEAM','OPPT','TEAMID','MATCH','GAMEID','RESULT','DATE','H/A',
                            'SPREAD','O/U','MIN','EFG%','FTA RATE','TOV%','OREB%','OPP EFG%',
                            'OPP FTA RATE','OPP TOV%','OPP OREB%','GP'])
for feature in columnsToRemove: fourFactorsFeatures.remove(feature)
print(fourFactorsFeatures)
# Out:
# ['EFG%L5MA', 'FTA RATEL5MA', 'TOV%L5MA', 'OREB%L5MA', 'OPP EFG%L5MA', 'OPP FTA RATEL5MA', 'OPP TOV%L5MA', 'OPP OREB%L5MA', 'EFG%L4MA', 'FTA RATEL4MA', 'TOV%L4MA', 'OREB%L4MA', 'OPP EFG%L4MA', 'OPP FTA RATEL4MA', 'OPP TOV%L4MA', 'OPP OREB%L4MA', 'EFG%L3MA', 'FTA RATEL3MA', 'TOV%L3MA', 'OREB%L3MA', 'OPP EFG%L3MA', 'OPP FTA RATEL3MA', 'OPP TOV%L3MA', 'OPP OREB%L3MA', 'EFG%L2MA', 'FTA RATEL2MA', 'TOV%L2MA', 'OREB%L2MA', 'OPP EFG%L2MA', 'OPP FTA RATEL2MA', 'OPP TOV%L2MA', 'OPP OREB%L2MA', 'EFG%L1MA', 'FTA RATEL1MA', 'TOV%L1MA', 'OREB%L1MA', 'OPP EFG%L1MA', 'OPP FTA RATEL1MA', 'OPP TOV%L1MA', 'OPP OREB%L1MA']

# %% [markdown]
# # Misc.csv

# %%
start_time = time.time()
miscDF = pd.read_csv('/Users/olutosinfashusi/jupyter/csv/fromNBADOTCOM/2023-24/byGame/Misc.csv')
miscDF = convertDateColumn(miscDF)
miscDF = featureEngineering('MISC',miscDF)
teamsDict = getTeamData('MISC',miscDF)
print("%s seconds" % (time.time() - start_time))
# Out:
# 19.0343120098114 seconds

# %%
start_time = time.time()
features = ['PTS OFF TO','2ND PTS','FBPS','PITP','OPP PTS OFF TO','OPP 2ND PTS','OPP FBPS','OPP PITP']
featureStringsDict = {}
for feature in features: featureStringsDict[feature] = feature+'LxMA' 
featureStringsDict    
addMovingAverageLx(featureStringsDict,teamsDict,5)
addMovingAverageLx(featureStringsDict,teamsDict,4)
addMovingAverageLx(featureStringsDict,teamsDict,3)
addMovingAverageLx(featureStringsDict,teamsDict,2)
addMovingAverageLx(featureStringsDict,teamsDict,1)

miscDF = addAdditionalFeatures(miscDF,teamsDict)
miscDF = miscDF.sort_values(by=['DATE','GAMEID','H/A']).reset_index(drop=True)
print("%s seconds" % (time.time() - start_time))
# Out:
# 4.295608043670654 seconds

# %%
miscFeatures = list(miscDF.columns)
columnsToRemove = np.array(['TEAM','OPPT','TEAMID','MATCH','GAMEID','RESULT','DATE','H/A','SPREAD',
                            'O/U','MIN','PTS OFF TO','2ND PTS','FBPS','PITP','OPP PTS OFF TO',
                            'OPP 2ND PTS','OPP FBPS','OPP PITP','GP'])
for feature in columnsToRemove: miscFeatures.remove(feature)
print(miscFeatures)
# Out:
# ['PTS OFF TOL5MA', '2ND PTSL5MA', 'FBPSL5MA', 'PITPL5MA', 'OPP PTS OFF TOL5MA', 'OPP 2ND PTSL5MA', 'OPP FBPSL5MA', 'OPP PITPL5MA', 'PTS OFF TOL4MA', '2ND PTSL4MA', 'FBPSL4MA', 'PITPL4MA', 'OPP PTS OFF TOL4MA', 'OPP 2ND PTSL4MA', 'OPP FBPSL4MA', 'OPP PITPL4MA', 'PTS OFF TOL3MA', '2ND PTSL3MA', 'FBPSL3MA', 'PITPL3MA', 'OPP PTS OFF TOL3MA', 'OPP 2ND PTSL3MA', 'OPP FBPSL3MA', 'OPP PITPL3MA', 'PTS OFF TOL2MA', '2ND PTSL2MA', 'FBPSL2MA', 'PITPL2MA', 'OPP PTS OFF TOL2MA', 'OPP 2ND PTSL2MA', 'OPP FBPSL2MA', 'OPP PITPL2MA', 'PTS OFF TOL1MA', '2ND PTSL1MA', 'FBPSL1MA', 'PITPL1MA', 'OPP PTS OFF TOL1MA', 'OPP 2ND PTSL1MA', 'OPP FBPSL1MA', 'OPP PITPL1MA']

# %% [markdown]
# # Scoring.csv

# %%
start_time = time.time()
scoringDF = pd.read_csv('/Users/olutosinfashusi/jupyter/csv/fromNBADOTCOM/2023-24/byGame/Scoring.csv')
scoringDF = convertDateColumn(scoringDF)
scoringDF = featureEngineering('SCORING',scoringDF)
teamsDict = getTeamData('SCORING',scoringDF)
print("%s seconds" % (time.time() - start_time))
# Out:
# 21.896794080734253 seconds

# %%
start_time = time.time()
features = ['%FGA 2PT','%FGA 3PT','%PTS 2PT','%PTS 2PT MR','%PTS 3PT','%PTS FBPS','%PTS FT',
            '%PTS OFF TO','%PTS PITP','2FGM %AST','2FGM %UAST','3FGM %AST','3FGM %UAST','FGM %AST','FGM %UAST']
featureStringsDict = {}
for feature in features: featureStringsDict[feature] = feature+'LxMA' 
featureStringsDict    
addMovingAverageLx(featureStringsDict,teamsDict,5)
addMovingAverageLx(featureStringsDict,teamsDict,4)
addMovingAverageLx(featureStringsDict,teamsDict,3)
addMovingAverageLx(featureStringsDict,teamsDict,2)
addMovingAverageLx(featureStringsDict,teamsDict,1)

scoringDF = addAdditionalFeatures(scoringDF,teamsDict)
scoringDF = scoringDF.sort_values(by=['DATE','GAMEID','H/A']).reset_index(drop=True)
print("%s seconds" % (time.time() - start_time))
# Out:
# 9.824681043624878 seconds

# %%
scoringFeatures = list(scoringDF.columns)
columnsToRemove = np.array(['TEAM','OPPT','TEAMID','MATCH','GAMEID','RESULT','DATE','H/A','SPREAD',
                            'O/U','MIN','%FGA 2PT','%FGA 3PT','%PTS 2PT','%PTS 2PT MR','%PTS 3PT',
                            '%PTS FBPS','%PTS FT','%PTS OFF TO','%PTS PITP','2FGM %AST','2FGM %UAST',
                            '3FGM %AST','3FGM %UAST','FGM %AST','FGM %UAST','GP'])
for feature in columnsToRemove: scoringFeatures.remove(feature)
print(scoringFeatures)
# Out:
# ['%FGA 2PTL5MA', '%FGA 3PTL5MA', '%PTS 2PTL5MA', '%PTS 2PT MRL5MA', '%PTS 3PTL5MA', '%PTS FBPSL5MA', '%PTS FTL5MA', '%PTS OFF TOL5MA', '%PTS PITPL5MA', '2FGM %ASTL5MA', '2FGM %UASTL5MA', '3FGM %ASTL5MA', '3FGM %UASTL5MA', 'FGM %ASTL5MA', 'FGM %UASTL5MA', '%FGA 2PTL4MA', '%FGA 3PTL4MA', '%PTS 2PTL4MA', '%PTS 2PT MRL4MA', '%PTS 3PTL4MA', '%PTS FBPSL4MA', '%PTS FTL4MA', '%PTS OFF TOL4MA', '%PTS PITPL4MA', '2FGM %ASTL4MA', '2FGM %UASTL4MA', '3FGM %ASTL4MA', '3FGM %UASTL4MA', 'FGM %ASTL4MA', 'FGM %UASTL4MA', '%FGA 2PTL3MA', '%FGA 3PTL3MA', '%PTS 2PTL3MA', '%PTS 2PT MRL3MA', '%PTS 3PTL3MA', '%PTS FBPSL3MA', '%PTS FTL3MA', '%PTS OFF TOL3MA', '%PTS PITPL3MA', '2FGM %ASTL3MA', '2FGM %UASTL3MA', '3FGM %ASTL3MA', '3FGM %UASTL3MA', 'FGM %ASTL3MA', 'FGM %UASTL3MA', '%FGA 2PTL2MA', '%FGA 3PTL2MA', '%PTS 2PTL2MA', '%PTS 2PT MRL2MA', '%PTS 3PTL2MA', '%PTS FBPSL2MA', '%PTS FTL2MA', '%PTS OFF TOL2MA', '%PTS PITPL2MA', '2FGM %ASTL2MA', '2FGM %UASTL2MA', '3FGM %ASTL2MA', '3FGM %UASTL2MA', 'FGM %ASTL2MA', 'FGM %UASTL2MA', '%FGA 2PTL1MA', '%FGA 3PTL1MA', '%PTS 2PTL1MA', '%PTS 2PT MRL1MA', '%PTS 3PTL1MA', '%PTS FBPSL1MA', '%PTS FTL1MA', '%PTS OFF TOL1MA', '%PTS PITPL1MA', '2FGM %ASTL1MA', '2FGM %UASTL1MA', '3FGM %ASTL1MA', '3FGM %UASTL1MA', 'FGM %ASTL1MA', 'FGM %UASTL1MA']

# %%
def train(NBAdf,features,date,maxDepth):
    models = {}
    NBAtrain = NBAdf[NBAdf['DATE'] < date].dropna()
    teamsPlayingToday = list(NBAdf[NBAdf['DATE'] == date]['TEAM'])
    for team in teamsPlayingToday:
        models[team] = {}
        models[team]['model'] = {}
        models[team]['trainSize'] = {}
    for team in teamsPlayingToday: 
        X_trainDF = pd.DataFrame()
        y_trainDF = pd.DataFrame()
        for feature in features:
            X_trainDF = pd.concat([X_trainDF,NBAtrain[NBAtrain['TEAM'] == team][feature]],axis=1)
        y_trainDF = NBAtrain[NBAtrain['TEAM'] == team]['RESULT']
        model = DecisionTreeClassifier(random_state=0,max_depth=maxDepth) #,min_samples_leaf=10)
        model.fit(X_trainDF,y_trainDF) 
        models[team]['model'] = model
        models[team]['trainSize'] = len(X_trainDF)
    return models
def test(NBAdf,features,date,models,modelResultDetails):
    teamsPlayingToday = list(NBAdf[NBAdf['DATE'] == date]['TEAM'])
    NBAtest = NBAdf[NBAdf['DATE'] == date] 
    for team in teamsPlayingToday:
        X_testDF = pd.DataFrame()
        y_testDF = pd.DataFrame()
        for feature in features:
            X_testDF = pd.concat([X_testDF,NBAtest[NBAtest['TEAM'] == team][feature]],axis=1)
        y_testDF = NBAtest[NBAtest['TEAM'] == team]['RESULT']
        paths = {}
        paths[team] = {}
        path = models[team]['model'].decision_path(X_testDF).indices #Return the decision path in the tree
        for i in range (len(path)):
            if models[team]['model'].tree_.children_left[path[i]] == -1 and models[team]['model'].tree_.children_right[path[i]] == -1: break;
            if path[i+1] == models[team]['model'].tree_.children_left[path[i]]:
                paths[team][i] = (X_testDF.columns[models[team]['model'].tree_.feature[path[i]]],
                                  float('%.3f'%models[team]['model'].tree_.threshold[path[i]]))
            if path[i+1] == models[team]['model'].tree_.children_right[path[i]]:
                paths[team][i] = (X_testDF.columns[models[team]['model'].tree_.feature[path[i]]],
                                  float('%.3f'%models[team]['model'].tree_.threshold[path[i]]))
        X_test = []
        for team in paths:
            for depth in paths[team]:
                feature = paths[team][depth][0]   #tuple
                threshold = paths[team][depth][1] #tuple
                X_test.append((feature,
                               float('%.3f'%X_testDF[feature].values[0]),
                               getTrueOrFalse(X_testDF[feature].values[0],threshold)))
        finalNodeDetails = (path[-1],
                            models[team]['model'].tree_.value[path[-1],0,0],
                            models[team]['model'].tree_.value[path[-1],0,1])
                            
        modelResultDetails[date][team] = {'DATE':date,
                                          'GAMEID':NBAtest[NBAtest['TEAM'] == team]['GAMEID'].values[0],
                                          'TRAIN SIZE':models[team]['trainSize'],
                                          'SPLIT DETAILS':paths[team],
                                          'X_test':X_test,
                                          'FINAL NODE DETAILS':finalNodeDetails,
                                          'PROBABILITY ESTIMATE':models[team]['model'].predict_proba(X_testDF)[0][1],
                                          'ACTUAL RESULT':y_testDF.values[0],
                                          'SPREAD':NBAtest[NBAtest['TEAM'] == team]['SPREAD'].values[0]}
def getTrueOrFalse(X_test,threshold):
    if X_test <= threshold: return 'T'
    else: return 'F'

# %% [markdown]
# # TRAIN ON PREVIOUS GAMES AND TEST ON TODAY'S GAMES

# %%
def trainTest(df,features):
    testDetails = {}
    dateOfNBAAllStarGame = datetime.date(2024,2,18)
    datesPostAllStarGame = np.unique(df[df['DATE'] > dateOfNBAAllStarGame]['DATE']).tolist()
    for date in datesPostAllStarGame:
        testDetails[date] = {}
        models = train(df,features,date,maxDepth=1)
        test(df,features,date,models,testDetails)
    return testDetails

# %%
traditionalTestDetails = trainTest(traditionalDF,traditionalFeatures)

# %%
advancedTestDetails = trainTest(advancedDF,advancedFeatures)

# %%
fourFactorsTestDetails = trainTest(fourFactorsDF,fourFactorsFeatures)

# %%
miscTestDetails = trainTest(miscDF,miscFeatures)

# %%
scoringTestDetails = trainTest(scoringDF,scoringFeatures)

# %%
NBATeams =['ATL','BKN','BOS','CHA','CHI','CLE','DAL','DEN','DET','GSW','HOU','IND',
           'LAC','LAL','MEM','MIA','MIL','MIN','NOP','NYK','OKC','ORL','PHI','PHX',
           'POR','SAC','SAS','TOR','UTA','WAS']

# %%
def getMatchResults(testDetailsDF):
    matchResultsDict = {'DATE':datetime.date,'MATCH':[],'GAMEID':[],'MODEL PREDICTS':[],
                        'ACTUAL WINNER':[],'BETTING FAVORITE':[]}
    for i in range (0,len(testDetailsDF),2):
        matchResultsDict['DATE'] = testDetailsDF.iloc[i]['DATE']
        matchResultsDict['MATCH'].append(testDetailsDF.iloc[i]['TEAM']+' @ '+testDetailsDF.iloc[i+1]['TEAM'])
        matchResultsDict['GAMEID'].append(testDetailsDF.iloc[i]['GAMEID'])
        matchResultsDict['MODEL PREDICTS'].append(getModelMatchPredicts(testDetailsDF.iloc[i],testDetailsDF.iloc[i+1]))
        matchResultsDict['ACTUAL WINNER'].append(getActualWinner(testDetailsDF.iloc[i],testDetailsDF.iloc[i+1]))
        matchResultsDict['BETTING FAVORITE'].append(getBettingFavorite(testDetailsDF.iloc[i],testDetailsDF.iloc[i+1]))
    matchResultsDict['DATE'] = (testDetailsDF.iloc[i]['DATE'])
    matchResultsDict['MATCH'].append(' ')
    matchResultsDict['GAMEID'].append(' ')
    matchResultsDict['MODEL PREDICTS'].append(' ')
    totalPredictions = len(matchResultsDict['ACTUAL WINNER'])
    correctPredictions = 0
    for i in range(len(matchResultsDict['ACTUAL WINNER'])):
        if matchResultsDict['ACTUAL WINNER'][i][1] == '✅': correctPredictions = correctPredictions + 1
    accuracy = correctPredictions / totalPredictions
    matchResultsDict['ACTUAL WINNER'].append(f'{accuracy:.1%}')
    totalPredictions = len(matchResultsDict['BETTING FAVORITE'])
    correctPredictions = 0
    for i in range(len(matchResultsDict['BETTING FAVORITE'])):
        if matchResultsDict['BETTING FAVORITE'][i][2] == '✅': correctPredictions = correctPredictions + 1
    accuracy = correctPredictions / totalPredictions
    matchResultsDict['BETTING FAVORITE'].append(f'{accuracy:.1%}')
    matchResultsDF = pd.DataFrame(matchResultsDict)
    return matchResultsDF
def getModelMatchPredicts(awayTeam,homeTeam):
    if awayTeam['PROBABILITY ESTIMATE'] == homeTeam['PROBABILITY ESTIMATE'] : return 'EQUAL P1s'
    if awayTeam['PROBABILITY ESTIMATE'] > homeTeam['PROBABILITY ESTIMATE']: return awayTeam['TEAM']
    if awayTeam['PROBABILITY ESTIMATE'] < homeTeam['PROBABILITY ESTIMATE']: return homeTeam['TEAM']
def getActualWinner(awayTeam,homeTeam):
    
    if awayTeam['PROBABILITY ESTIMATE'] == homeTeam['PROBABILITY ESTIMATE'] : return 'EQUAL P1s'
    if awayTeam['ACTUAL RESULT'] == 1 and awayTeam['PROBABILITY ESTIMATE'] > homeTeam['PROBABILITY ESTIMATE']:
        return awayTeam['TEAM'],'✅'
    if awayTeam['ACTUAL RESULT'] == 1 and awayTeam['PROBABILITY ESTIMATE'] < homeTeam['PROBABILITY ESTIMATE']:
        return awayTeam['TEAM'],'❌'
    if homeTeam['ACTUAL RESULT'] == 1 and awayTeam['PROBABILITY ESTIMATE'] < homeTeam['PROBABILITY ESTIMATE']:
        return homeTeam['TEAM'],'✅'
    if homeTeam['ACTUAL RESULT'] == 1 and awayTeam['PROBABILITY ESTIMATE'] > homeTeam['PROBABILITY ESTIMATE']:
        return homeTeam['TEAM'],'❌'
    
def getBettingFavorite(awayTeam,homeTeam):
    if awayTeam['PROBABILITY ESTIMATE'] == homeTeam['PROBABILITY ESTIMATE'] : return 'EQUAL P1s'
    if awayTeam['SPREAD'] < 0:
        if awayTeam['PROBABILITY ESTIMATE'] > homeTeam['PROBABILITY ESTIMATE']:
            return awayTeam['TEAM'],awayTeam['SPREAD'],'✅'
        else: return awayTeam['TEAM'],awayTeam['SPREAD'],'❌'
    else:
        if homeTeam['PROBABILITY ESTIMATE'] > awayTeam['PROBABILITY ESTIMATE']:
            return homeTeam['TEAM'],homeTeam['SPREAD'],'✅'
        else: return homeTeam['TEAM'],homeTeam['SPREAD'],'❌'

# %%
traditionalMatchResults = {}
dateOfNBAAllStarGame = datetime.date(2024,2,18)
datesPostAllStarGame = np.unique(traditionalDF[traditionalDF['DATE'] > dateOfNBAAllStarGame]['DATE']).tolist()
for date in datesPostAllStarGame:
    traditionalMatchResults[date] = {}
for key in traditionalTestDetails.keys():
    df = pd.DataFrame(traditionalTestDetails[key]).T.reset_index(drop=False).rename(columns=({'index':'TEAM'}))
    traditionalMatchResults[key] = getMatchResults(df)

# %%
advancedMatchResults = {}
dateOfNBAAllStarGame = datetime.date(2024,2,18)
datesPostAllStarGame = np.unique(advancedDF[advancedDF['DATE'] > dateOfNBAAllStarGame]['DATE']).tolist()
for date in datesPostAllStarGame:
    advancedMatchResults[date] = {}
for key in advancedTestDetails.keys():
    df = pd.DataFrame(advancedTestDetails[key]).T.reset_index(drop=False).rename(columns=({'index':'TEAM'}))
    advancedMatchResults[key] = getMatchResults(df)

# %%
fourFactorsMatchResults = {}
dateOfNBAAllStarGame = datetime.date(2024,2,18)
datesPostAllStarGame = np.unique(fourFactorsDF[fourFactorsDF['DATE'] > dateOfNBAAllStarGame]['DATE']).tolist()
for date in datesPostAllStarGame:
    fourFactorsMatchResults[date] = {}
for key in fourFactorsTestDetails.keys():
    df = pd.DataFrame(fourFactorsTestDetails[key]).T.reset_index(drop=False).rename(columns=({'index':'TEAM'}))
    fourFactorsMatchResults[key] = getMatchResults(df)

# %%
miscMatchResults = {}
dateOfNBAAllStarGame = datetime.date(2024,2,18)
datesPostAllStarGame = np.unique(miscDF[miscDF['DATE'] > dateOfNBAAllStarGame]['DATE']).tolist()
for date in datesPostAllStarGame:
    miscMatchResults[date] = {}
for key in miscTestDetails.keys():
    df = pd.DataFrame(miscTestDetails[key]).T.reset_index(drop=False).rename(columns=({'index':'TEAM'}))
    miscMatchResults[key] = getMatchResults(df)

# %%
scoringMatchResults = {}
dateOfNBAAllStarGame = datetime.date(2024,2,18)
datesPostAllStarGame = np.unique(scoringDF[scoringDF['DATE'] > dateOfNBAAllStarGame]['DATE']).tolist()
for date in datesPostAllStarGame:
    scoringMatchResults[date] = {}
for key in scoringTestDetails.keys():
    df = pd.DataFrame(scoringTestDetails[key]).T.reset_index(drop=False).rename(columns=({'index':'TEAM'}))
    scoringMatchResults[key] = getMatchResults(df)

# %%
def getModelPredictions(matchResults):
    datesPostAllStarGame = list(matchResults.keys())
    predictions = []
    for date in datesPostAllStarGame:
        predictions.append(matchResults[date])
    return predictions
def getActualAccuracy(df):
    correct = 0
    incorrect = 0
    count = 0
    for i in range(len(df.reset_index(drop=True))):
        if df.iloc[i]['MODEL PREDICTS'] != ' ' or df.iloc[i]['MODEL PREDICTS'] != 'EQUAL P1s':
            if df.iloc[i]['ACTUAL WINNER'][1] == '❌':
                count = count + 1 
                incorrect = incorrect + 1
            if df.iloc[i]['ACTUAL WINNER'][1] == '✅':
                count = count + 1 
                correct = correct + 1
    accuracy = correct/(correct+incorrect)
    print(count)
    return f'{accuracy:.1%}'
def getBettingFavoriteAccuracy(df):
    correct = 0
    incorrect = 0
    for i in range(len(df.reset_index(drop=True))):
        if df.iloc[i]['MODEL PREDICTS'] != ' ' or df.iloc[i]['MODEL PREDICTS'] != 'EQUAL P1s':
            if df.iloc[i]['BETTING FAVORITE'][2] == '❌': 
                incorrect = incorrect + 1
            if df.iloc[i]['BETTING FAVORITE'][2] == '✅': 
                correct = correct + 1
    accuracy = correct/(correct+incorrect)
    return f'{accuracy:.1%}'

# %%
#

# %%
traditionalMatchResults[datetime.date(2024, 2, 22)]
# Out:
#           DATE      MATCH    GAMEID MODEL PREDICTS ACTUAL WINNER BETTING FAVORITE
# 0   2024-02-22  ORL @ CLE  22300792            CLE      (ORL, ❌)   (CLE, -5.0, ✅)
# 1   2024-02-22  DET @ IND  22300793            IND      (IND, ✅)  (IND, -12.0, ✅)
# 2   2024-02-22  NYK @ PHI  22300794            NYK      (NYK, ✅)   (PHI, -1.5, ❌)
# 3   2024-02-22  BKN @ TOR  22300795            TOR      (TOR, ✅)   (TOR, -1.5, ✅)
# 4   2024-02-22  PHX @ DAL  22300796            DAL      (DAL, ✅)   (DAL, -2.5, ✅)
# 5   2024-02-22  BOS @ CHI  22300797            BOS      (BOS, ✅)   (BOS, -8.5, ✅)
# 6   2024-02-22  HOU @ NOP  22300798            NOP      (NOP, ✅)   (NOP, -6.5, ✅)
# 7   2024-02-22  LAC @ OKC  22300799            OKC      (OKC, ✅)   (OKC, -1.5, ✅)
# 8   2024-02-22  WAS @ DEN  22300800            DEN      (DEN, ✅)  (DEN, -15.5, ✅)
# 9   2024-02-22  CHA @ UTA  22300801            UTA      (CHA, ❌)   (UTA, -9.5, ✅)
# 10  2024-02-22  LAL @ GSW  22300802            GSW      (GSW, ✅)   (GSW, -6.0, ✅)
# 11  2024-02-22  SAS @ SAC  22300803            SAC      (SAC, ✅)  (SAC, -10.5, ✅)
# 12  2024-02-22                                             83.3%            91.7%

# %%
boxScoreTypes = [traditionalMatchResults,advancedMatchResults,fourFactorsMatchResults,
                 miscMatchResults,scoringMatchResults]
actualAccuracies = []
bettingFavoriteAccuracies = []
totalPredictions = 0
for boxScore in boxScoreTypes:
    actualAccuracies.append(getActualAccuracy(pd.concat(getModelPredictions(boxScore))))
    bettingFavoriteAccuracies.append(getBettingFavoriteAccuracy(pd.concat(getModelPredictions(boxScore))))
# Out:
# 409
# 410
# 408
# 409
# 410

# %%
409+410+408+409+410
# Out:
# 2046

# %%
pd.concat(getModelPredictions(traditionalMatchResults))
# Out:
#           DATE      MATCH    GAMEID MODEL PREDICTS ACTUAL WINNER BETTING FAVORITE
# 0   2024-02-22  ORL @ CLE  22300792            CLE      (ORL, ❌)   (CLE, -5.0, ✅)
# 1   2024-02-22  DET @ IND  22300793            IND      (IND, ✅)  (IND, -12.0, ✅)
# 2   2024-02-22  NYK @ PHI  22300794            NYK      (NYK, ✅)   (PHI, -1.5, ❌)
# 3   2024-02-22  BKN @ TOR  22300795            TOR      (TOR, ✅)   (TOR, -1.5, ✅)
# 4   2024-02-22  PHX @ DAL  22300796            DAL      (DAL, ✅)   (DAL, -2.5, ✅)
# 5   2024-02-22  BOS @ CHI  22300797            BOS      (BOS, ✅)   (BOS, -8.5, ✅)
# 6   2024-02-22  HOU @ NOP  22300798            NOP      (NOP, ✅)   (NOP, -6.5, ✅)
# 7   2024-02-22  LAC @ OKC  22300799            OKC      (OKC, ✅)   (OKC, -1.5, ✅)
# 8   2024-02-22  WAS @ DEN  22300800            DEN      (DEN, ✅)  (DEN, -15.5, ✅)
# 9   2024-02-22  CHA @ UTA  22300801            UTA      (CHA, ❌)   (UTA, -9.5, ✅)
# 10  2024-02-22  LAL @ GSW  22300802            GSW      (GSW, ✅)   (GSW, -6.0, ✅)
# 11  2024-02-22  SAS @ SAC  22300803            SAC      (SAC, ✅)  (SAC, -10.5, ✅)
# 12  2024-02-22                                             83.3%            91.7%
# 0   2024-02-23  TOR @ ATL  22300804            TOR      (TOR, ✅)   (ATL, -7.5, ❌)
# 1   2024-02-23  CLE @ PHI  22300805            CLE      (PHI, ❌)   (CLE, -2.0, ✅)
# 2   2024-02-23  PHX @ HOU  22300806            PHX      (HOU, ❌)   (PHX, -3.0, ✅)
# 3   2024-02-23  LAC @ MEM  22300807            LAC      (LAC, ✅)   (LAC, -9.5, ✅)
# 4   2024-02-23  MIL @ MIN  22300808            MIN      (MIL, ❌)   (MIN, -4.5, ✅)
# 5   2024-02-23  WAS @ OKC  22300809            OKC      (OKC, ✅)  (OKC, -16.0, ✅)
# 6   2024-02-23  MIA @ NOP  22300810            MIA      (MIA, ✅)   (NOP, -2.0, ❌)
# 7   2024-02-23  CHA @ GSW  22300811            GSW      (GSW, ✅)  (GSW, -12.5, ✅)
# 8   2024-02-23  DEN @ POR  22300812            DEN      (DEN, ✅)   (DEN, -8.5, ✅)
# 9   2024-02-23  SAS @ LAL  22300813            LAL      (LAL, ✅)  (LAL, -11.0, ✅)
# 10  2024-02-23                                             70.0%            80.0%
# 0   2024-02-24  ORL @ DET  22300814            ORL      (ORL, ✅)   (ORL, -8.0, ✅)
# 1   2024-02-24  BKN @ MIN  22300815            MIN      (MIN, ✅)   (MIN, -8.0, ✅)
# 2   2024-02-24  BOS @ NYK  22300816            NYK      (BOS, ❌)   (BOS, -6.0, ❌)
# 3   2024-02-24                                             66.7%            66.7%
# 0   2024-02-25  MIL @ PHI  22300817            MIL      (MIL, ✅)   (MIL, -4.5, ✅)
# 1   2024-02-25  LAL @ PHX  22300818            LAL      (PHX, ❌)   (PHX, -3.5, ❌)
# 2   2024-02-25  DAL @ IND  22300819            IND      (IND, ✅)   (DAL, -2.0, ❌)
# 3   2024-02-25  CLE @ WAS  22300820            CLE      (CLE, ✅)  (CLE, -13.5, ✅)
# 4   2024-02-25  ORL @ ATL  22300821            ORL      (ATL, ❌)   (ATL, -2.0, ❌)
# 5   2024-02-25  OKC @ HOU  22300822            OKC      (OKC, ✅)   (OKC, -6.5, ✅)
# 6   2024-02-25  CHI @ NOP  22300823            NOP      (CHI, ❌)   (NOP, -5.0, ✅)
# 7   2024-02-25  DEN @ GSW  22300824            GSW      (DEN, ❌)   (GSW, -1.5, ✅)
# 8   2024-02-25  SAS @ UTA  22300825            UTA      (UTA, ✅)   (UTA, -6.5, ✅)
# 9   2024-02-25  CHA @ POR  22300826            POR      (CHA, ❌)   (POR, -3.5, ✅)
# 10  2024-02-25  SAC @ LAC  22300827            LAC      (SAC, ❌)   (LAC, -4.0, ✅)
# 11  2024-02-25                                             45.5%            72.7%
# 0   2024-02-26  DET @ NYK  22300828            NYK      (NYK, ✅)  (NYK, -11.0, ✅)
# 1   2024-02-26  TOR @ IND  22300829            IND      (TOR, ❌)   (IND, -5.5, ✅)
# 2   2024-02-26  BKN @ MEM  22300830            MEM      (BKN, ❌)   (BKN, -2.5, ❌)
# 3   2024-02-26  MIA @ SAC  22300831            SAC      (MIA, ❌)   (SAC, -7.5, ✅)
# 4   2024-02-26                                             25.0%            75.0%
# 0   2024-02-27  DAL @ CLE  22300832            CLE      (CLE, ✅)   (CLE, -4.0, ✅)
# 1   2024-02-27  BKN @ ORL  22300833            ORL      (ORL, ✅)   (ORL, -6.5, ✅)
# 2   2024-02-27  GSW @ WAS  22300834            GSW      (GSW, ✅)  (GSW, -10.5, ✅)
# 3   2024-02-27  UTA @ ATL  22300835            ATL      (ATL, ✅)   (ATL, -1.5, ✅)
# 4   2024-02-27  PHI @ BOS  22300836            BOS      (BOS, ✅)  (BOS, -11.5, ✅)
# 5   2024-02-27  NOP @ NYK  22300837            NYK      (NOP, ❌)   (NOP, -6.5, ❌)
# 6   2024-02-27  SAS @ MIN  22300838            MIN      (MIN, ✅)  (MIN, -13.0, ✅)
# 7   2024-02-27  DET @ CHI  22300839            CHI      (DET, ❌)   (CHI, -9.5, ✅)
# 8   2024-02-27  CHA @ MIL  22300840            CHA      (MIL, ❌)  (MIL, -14.0, ❌)
# 9   2024-02-27  HOU @ OKC  22300841            HOU      (OKC, ❌)  (OKC, -10.0, ❌)
# 10  2024-02-27  MIA @ POR  22300842            MIA      (MIA, ✅)   (MIA, -7.0, ✅)
# 11  2024-02-27                                             63.6%            72.7%
# 0   2024-02-28  NOP @ IND  22300843            NOP      (IND, ❌)   (IND, -4.0, ❌)
# 1   2024-02-28  DAL @ TOR  22300844            DAL      (DAL, ✅)   (DAL, -4.0, ✅)
# 2   2024-02-28  MEM @ MIN  22300845            MIN      (MIN, ✅)  (MIN, -13.5, ✅)
# 3   2024-02-28  CLE @ CHI  22300846            CLE      (CHI, ❌)   (CLE, -5.5, ✅)
# 4   2024-02-28  SAC @ DEN  22300847            DEN      (DEN, ✅)   (DEN, -9.5, ✅)
# 5   2024-02-28  LAL @ LAC  22300848            LAC      (LAL, ❌)   (LAC, -1.5, ✅)
# 6   2024-02-28                                             50.0%            83.3%
# 0   2024-02-29  MIL @ CHA  22300849            CHA      (MIL, ❌)  (MIL, -11.5, ❌)
# 1   2024-02-29  UTA @ ORL  22300850            ORL      (ORL, ✅)   (ORL, -7.5, ✅)
# 2   2024-02-29  ATL @ BKN  22300851            ATL      (BKN, ❌)   (BKN, -1.5, ❌)
# 3   2024-02-29  GSW @ NYK  22300852            NYK      (GSW, ❌)   (GSW, -3.5, ❌)
# 4   2024-02-29  OKC @ SAS  22300853            OKC      (SAS, ❌)  (OKC, -11.0, ✅)
# 5   2024-02-29  HOU @ PHX  22300854            HOU      (PHX, ❌)   (PHX, -8.5, ❌)
# 6   2024-02-29  MIA @ DEN  22300855            DEN      (DEN, ✅)   (DEN, -6.5, ✅)
# 7   2024-02-29  WAS @ LAL  22300856            LAL      (LAL, ✅)  (LAL, -11.0, ✅)
# 8   2024-02-29                                             37.5%            50.0%
# 0   2024-03-01  CLE @ DET  22300857            DET      (CLE, ❌)   (CLE, -7.0, ❌)
# 1   2024-03-01  CHA @ PHI  22300858            PHI      (PHI, ✅)  (PHI, -12.0, ✅)
# 2   2024-03-01  DAL @ BOS  22300859            BOS      (BOS, ✅)   (BOS, -8.5, ✅)
# 3   2024-03-01  GSW @ TOR  22300860            GSW      (GSW, ✅)   (GSW, -3.0, ✅)
# 4   2024-03-01  POR @ MEM  22300861            MEM      (POR, ❌)   (MEM, -1.0, ✅)
# 5   2024-03-01  SAC @ MIN  22300862            SAC      (SAC, ✅)   (MIN, -8.5, ❌)
# 6   2024-03-01  IND @ NOP  22300863            NOP      (NOP, ✅)   (NOP, -5.0, ✅)
# 7   2024-03-01  MIL @ CHI  22300864            MIL      (MIL, ✅)   (MIL, -4.0, ✅)
# 8   2024-03-01  WAS @ LAC  22300865            WAS      (LAC, ❌)  (LAC, -16.0, ❌)
# 9   2024-03-01                                             66.7%            66.7%
# 0   2024-03-02  ATL @ BKN  22300866            ATL      (BKN, ❌)   (ATL, -1.0, ✅)
# 1   2024-03-02  UTA @ MIA  22300867            UTA      (MIA, ❌)   (MIA, -9.0, ❌)
# 2   2024-03-02  POR @ MEM  22300868            MEM      (POR, ❌)   (MEM, -2.5, ✅)
# 3   2024-03-02  DEN @ LAL  22300869            DEN      (DEN, ✅)   (DEN, -1.0, ✅)
# 4   2024-03-02  HOU @ PHX  22300870            HOU      (HOU, ✅)   (PHX, -9.0, ❌)
# 5   2024-03-02                                             40.0%            60.0%
# 0   2024-03-03  PHI @ DAL  22300871            DAL      (PHI, ❌)   (DAL, -7.5, ✅)
# 1   2024-03-03  GSW @ BOS  22300872            BOS      (BOS, ✅)   (BOS, -8.0, ✅)
# 2   2024-03-03  LAC @ MIN  22300873            MIN      (LAC, ❌)   (MIN, -2.5, ✅)
# 3   2024-03-03  DET @ ORL  22300874            ORL      (ORL, ✅)  (ORL, -11.0, ✅)
# 4   2024-03-03  CHA @ TOR  22300875            TOR      (TOR, ✅)   (TOR, -7.0, ✅)
# 5   2024-03-03  NYK @ CLE  22300876            NYK      (NYK, ✅)   (CLE, -4.0, ❌)
# 6   2024-03-03  IND @ SAS  22300877            SAS      (SAS, ✅)   (IND, -6.5, ❌)
# 7   2024-03-03  OKC @ PHX  22300878            PHX      (OKC, ❌)   (OKC, -4.5, ❌)
# 8   2024-03-03                                             62.5%            62.5%
# 0   2024-03-04  MEM @ BKN  22300879            BKN      (MEM, ❌)   (BKN, -9.5, ✅)
# 1   2024-03-04  LAC @ MIL  22300880      EQUAL P1s     EQUAL P1s        EQUAL P1s
# 2   2024-03-04  POR @ MIN  22300881            MIN      (MIN, ✅)  (MIN, -15.0, ✅)
# 3   2024-03-04  WAS @ UTA  22300882            UTA      (UTA, ✅)   (UTA, -5.0, ✅)
# 4   2024-03-04  CHI @ SAC  22300883            CHI      (CHI, ✅)   (SAC, -6.5, ❌)
# 5   2024-03-04  OKC @ LAL  22300884            LAL      (LAL, ✅)   (OKC, -1.0, ❌)
# 6   2024-03-04                                             66.7%            50.0%
# 0   2024-03-05  ORL @ CHA  22300885            ORL      (ORL, ✅)   (ORL, -8.5, ✅)
# 1   2024-03-05  BOS @ CLE  22300886            CLE      (CLE, ✅)   (BOS, -8.5, ❌)
# 2   2024-03-05  PHI @ BKN  22300887            PHI      (BKN, ❌)   (BKN, -1.0, ❌)
# 3   2024-03-05  DET @ MIA  22300888            MIA      (MIA, ✅)  (MIA, -11.0, ✅)
# 4   2024-03-05  ATL @ NYK  22300889            NYK      (ATL, ❌)   (NYK, -1.0, ✅)
# 5   2024-03-05  NOP @ TOR  22300890            NOP      (NOP, ✅)   (NOP, -9.0, ✅)
# 6   2024-03-05  SAS @ HOU  22300891            HOU      (HOU, ✅)   (HOU, -7.0, ✅)
# 7   2024-03-05  IND @ DAL  22300892            DAL      (IND, ❌)   (DAL, -5.5, ✅)
# 8   2024-03-05  PHX @ DEN  22300893            DEN      (PHX, ❌)   (DEN, -9.0, ✅)
# 9   2024-03-05                                             55.6%            77.8%
# 0   2024-03-06  ORL @ WAS  22300894            ORL      (ORL, ✅)   (ORL, -6.5, ✅)
# 1   2024-03-06  CLE @ ATL  22300895            CLE      (ATL, ❌)   (ATL, -3.0, ❌)
# 2   2024-03-06  MEM @ PHI  22300896            PHI      (MEM, ❌)   (PHI, -4.0, ✅)
# 3   2024-03-06  LAC @ HOU  22300897            LAC      (LAC, ✅)   (LAC, -6.5, ✅)
# 4   2024-03-06  CHI @ UTA  22300898            UTA      (CHI, ❌)   (CHI, -4.0, ❌)
# 5   2024-03-06  MIL @ GSW  22300899            MIL      (GSW, ❌)   (GSW, -2.5, ❌)
# 6   2024-03-06  OKC @ POR  22300900            OKC      (OKC, ✅)  (OKC, -13.0, ✅)
# 7   2024-03-06  SAC @ LAL  22300901            SAC      (SAC, ✅)   (LAL, -3.0, ❌)
# 8   2024-03-06                                             50.0%            50.0%
# 0   2024-03-07  BKN @ DET  22300902            BKN      (DET, ❌)   (BKN, -2.5, ✅)
# 1   2024-03-07  MIN @ IND  22300903            MIN      (MIN, ✅)   (IND, -1.5, ❌)
# 2   2024-03-07  MIA @ DAL  22300904            MIA      (DAL, ❌)   (DAL, -4.5, ❌)
# 3   2024-03-07  TOR @ PHX  22300905            PHX      (PHX, ✅)  (PHX, -10.5, ✅)
# 4   2024-03-07  BOS @ DEN  22300906            DEN      (DEN, ✅)   (BOS, -2.0, ❌)
# 5   2024-03-07  CHI @ GSW  22300907            GSW      (CHI, ❌)   (GSW, -8.5, ✅)
# 6   2024-03-07  SAS @ SAC  22300908            SAC      (SAC, ✅)  (SAC, -12.0, ✅)
# 7   2024-03-07                                             57.1%            57.1%
# 0   2024-03-08  NOP @ PHI  22300909            PHI      (NOP, ❌)   (NOP, -8.0, ❌)
# 1   2024-03-08  CHA @ WAS  22300910            CHA      (WAS, ❌)   (WAS, -2.5, ❌)
# 2   2024-03-08  MIN @ CLE  22300911            CLE      (CLE, ✅)   (CLE, -1.0, ✅)
# 3   2024-03-08  ORL @ NYK  22300912            ORL      (NYK, ❌)   (NYK, -3.0, ❌)
# 4   2024-03-08  ATL @ MEM  22300913            ATL      (ATL, ✅)   (ATL, -3.5, ✅)
# 5   2024-03-08  MIA @ OKC  22300914            OKC      (OKC, ✅)   (OKC, -8.5, ✅)
# 6   2024-03-08  MIL @ LAL  22300915            LAL      (LAL, ✅)   (MIL, -4.0, ❌)
# 7   2024-03-08  HOU @ POR  22300916            HOU      (HOU, ✅)   (HOU, -6.5, ✅)
# 8   2024-03-08                                             62.5%            50.0%
# 0   2024-03-09  CHI @ LAC  22300917            CHI      (LAC, ❌)   (LAC, -8.0, ❌)
# 1   2024-03-09  BKN @ CHA  22300918            BKN      (CHA, ❌)   (BKN, -6.5, ✅)
# 2   2024-03-09  DAL @ DET  22300919            DAL      (DAL, ✅)   (DAL, -9.0, ✅)
# 3   2024-03-09  BOS @ PHX  22300920            BOS      (BOS, ✅)   (BOS, -5.5, ✅)
# 4   2024-03-09  SAS @ GSW  22300921            GSW      (SAS, ❌)  (GSW, -12.5, ✅)
# 5   2024-03-09  UTA @ DEN  22300922            DEN      (DEN, ✅)  (DEN, -12.5, ✅)
# 6   2024-03-09  TOR @ POR  22300923            POR      (POR, ✅)   (TOR, -2.0, ❌)
# 7   2024-03-09                                             57.1%            71.4%
# 0   2024-03-10  MIL @ LAC  22300924            LAC      (MIL, ❌)   (MIL, -6.5, ❌)
# 1   2024-03-10  NOP @ ATL  22300925            NOP      (NOP, ✅)   (NOP, -7.0, ✅)
# 2   2024-03-10  WAS @ MIA  22300926            MIA      (WAS, ❌)  (MIA, -11.5, ✅)
# 3   2024-03-10  PHI @ NYK  22300927            NYK      (PHI, ❌)   (NYK, -7.0, ✅)
# 4   2024-03-10  IND @ ORL  22300928            IND      (IND, ✅)   (IND, -1.0, ✅)
# 5   2024-03-10  HOU @ SAC  22300929            SAC      (HOU, ❌)   (SAC, -7.0, ✅)
# 6   2024-03-10  BKN @ CLE  22300930            CLE      (BKN, ❌)   (CLE, -6.5, ✅)
# 7   2024-03-10  MEM @ OKC  22300931            OKC      (OKC, ✅)  (OKC, -15.0, ✅)
# 8   2024-03-10  MIN @ LAL  22300932            MIN      (LAL, ❌)   (LAL, -5.0, ❌)
# 9   2024-03-10                                             33.3%            77.8%
# 0   2024-03-11  CHA @ DET  22300933            DET      (DET, ✅)   (DET, -5.0, ✅)
# 1   2024-03-11  PHX @ CLE  22300934            CLE      (PHX, ❌)   (PHX, -7.0, ❌)
# 2   2024-03-11  DAL @ CHI  22300935            CHI      (DAL, ❌)   (DAL, -3.5, ❌)
# 3   2024-03-11  GSW @ SAS  22300936            GSW      (GSW, ✅)   (GSW, -5.0, ✅)
# 4   2024-03-11  TOR @ DEN  22300937            TOR      (DEN, ❌)  (DEN, -17.5, ❌)
# 5   2024-03-11  BOS @ POR  22300938            BOS      (BOS, ✅)  (BOS, -11.5, ✅)
# 6   2024-03-11                                             50.0%            50.0%
# 0   2024-03-12  PHI @ NYK  22300939            PHI      (NYK, ❌)   (NYK, -6.0, ❌)
# 1   2024-03-12  WAS @ MEM  22300940            WAS      (MEM, ❌)   (WAS, -2.5, ✅)
# 2   2024-03-12  IND @ OKC  22300941            OKC      (IND, ❌)   (OKC, -5.5, ✅)
# 3   2024-03-12  HOU @ SAS  22300942            HOU      (HOU, ✅)   (HOU, -3.0, ✅)
# 4   2024-03-12  BOS @ UTA  22300943            BOS      (BOS, ✅)   (BOS, -6.5, ✅)
# 5   2024-03-12  MIN @ LAC  22300944            MIN      (MIN, ✅)   (LAC, -5.5, ❌)
# 6   2024-03-12  MIL @ SAC  22300945            MIL      (SAC, ❌)   (SAC, -1.5, ❌)
# 7   2024-03-12                                             42.9%            57.1%
# 0   2024-03-13  TOR @ DET  22300946            DET      (DET, ✅)   (DET, -3.5, ✅)
# 1   2024-03-13  BKN @ ORL  22300947            ORL      (ORL, ✅)   (ORL, -6.0, ✅)
# 2   2024-03-13  CHI @ IND  22300948            CHI      (CHI, ✅)   (IND, -5.0, ❌)
# 3   2024-03-13  DEN @ MIA  22300949            MIA      (DEN, ❌)   (DEN, -3.5, ❌)
# 4   2024-03-13  CHA @ MEM  22300950            MEM      (CHA, ❌)   (CHA, -2.5, ❌)
# 5   2024-03-13  CLE @ NOP  22300951            CLE      (CLE, ✅)   (NOP, -6.0, ❌)
# 6   2024-03-13  GSW @ DAL  22300952            DAL      (DAL, ✅)   (DAL, -8.5, ✅)
# 7   2024-03-13  ATL @ POR  22300953            POR      (POR, ✅)   (ATL, -4.0, ❌)
# 8   2024-03-13  LAL @ SAC  22300954            LAL      (SAC, ❌)   (LAL, -2.5, ✅)
# 9   2024-03-13                                             66.7%            44.4%
# 0   2024-03-14  PHX @ BOS  22300955            BOS      (BOS, ✅)   (BOS, -5.5, ✅)
# 1   2024-03-14  LAC @ CHI  22300956            CHI      (LAC, ❌)   (LAC, -6.0, ❌)
# 2   2024-03-14  WAS @ HOU  22300957            WAS      (HOU, ❌)   (HOU, -8.5, ❌)
# 3   2024-03-14  PHI @ MIL  22300958            MIL      (MIL, ✅)   (MIL, -7.0, ✅)
# 4   2024-03-14  DAL @ OKC  22300959            DAL      (OKC, ❌)   (OKC, -9.5, ❌)
# 5   2024-03-14  NYK @ POR  22300960            POR      (NYK, ❌)  (NYK, -12.0, ❌)
# 6   2024-03-14                                             33.3%            33.3%
# 0   2024-03-15  PHX @ CHA  22300961            PHX      (PHX, ✅)  (PHX, -10.5, ✅)
# 1   2024-03-15  MIA @ DET  22300962            MIA      (MIA, ✅)   (MIA, -7.5, ✅)
# 2   2024-03-15  ORL @ TOR  22300963            ORL      (ORL, ✅)   (ORL, -8.0, ✅)
# 3   2024-03-15  LAC @ NOP  22300964            LAC      (NOP, ❌)   (NOP, -7.0, ❌)
# 4   2024-03-15  DEN @ SAS  22300965            DEN      (DEN, ✅)  (DEN, -10.5, ✅)
# 5   2024-03-15  ATL @ UTA  22300966            UTA      (UTA, ✅)   (ATL, -1.0, ❌)
# 6   2024-03-15                                             83.3%            66.7%
# 0   2024-03-16  CLE @ HOU  22300967            CLE      (HOU, ❌)   (CLE, -5.0, ✅)
# 1   2024-03-16  BKN @ IND  22300968            IND      (IND, ✅)   (IND, -8.5, ✅)
# 2   2024-03-16  CHA @ PHI  22300969            PHI      (PHI, ✅)  (PHI, -10.5, ✅)
# 3   2024-03-16  POR @ NOP  22300970            NOP      (NOP, ✅)  (NOP, -13.0, ✅)
# 4   2024-03-16  WAS @ CHI  22300971            CHI      (CHI, ✅)   (CHI, -9.5, ✅)
# 5   2024-03-16  OKC @ MEM  22300972            OKC      (OKC, ✅)  (OKC, -10.5, ✅)
# 6   2024-03-16  GSW @ LAL  22300973            LAL      (GSW, ❌)   (LAL, -1.5, ✅)
# 7   2024-03-16  MIN @ UTA  22300974            MIN      (MIN, ✅)   (MIN, -7.5, ✅)
# 8   2024-03-16  NYK @ SAC  22300975            NYK      (NYK, ✅)   (SAC, -3.0, ❌)
# 9   2024-03-16                                             77.8%            88.9%
# 0   2024-03-17  PHX @ MIL  22300976            PHX      (MIL, ❌)   (PHX, -2.5, ✅)
# 1   2024-03-17  MIA @ DET  22300977            DET      (MIA, ❌)   (MIA, -5.5, ❌)
# 2   2024-03-17  DEN @ DAL  22300978            DEN      (DAL, ❌)   (DEN, -1.0, ✅)
# 3   2024-03-17  TOR @ ORL  22300979            ORL      (ORL, ✅)  (ORL, -11.0, ✅)
# 4   2024-03-17  BOS @ WAS  22300980            BOS      (BOS, ✅)  (BOS, -14.5, ✅)
# 5   2024-03-17  BKN @ SAS  22300981            BKN      (SAS, ❌)   (SAS, -2.0, ❌)
# 6   2024-03-17  ATL @ LAC  22300982            LAC      (ATL, ❌)   (LAC, -9.5, ✅)
# 7   2024-03-17                                             28.6%            71.4%
# 0   2024-03-18  CLE @ IND  22300983            CLE      (CLE, ✅)   (IND, -6.5, ❌)
# 1   2024-03-18  DET @ BOS  22300984            BOS      (BOS, ✅)  (BOS, -15.0, ✅)
# 2   2024-03-18  MIA @ PHI  22300985            PHI      (PHI, ✅)   (PHI, -3.0, ✅)
# 3   2024-03-18  POR @ CHI  22300986            CHI      (CHI, ✅)   (CHI, -8.5, ✅)
# 4   2024-03-18  MIN @ UTA  22300987            UTA      (MIN, ❌)   (MIN, -4.0, ❌)
# 5   2024-03-18  NYK @ GSW  22300988            GSW      (NYK, ❌)   (GSW, -7.0, ✅)
# 6   2024-03-18  MEM @ SAC  22300989            SAC      (SAC, ✅)  (SAC, -11.5, ✅)
# 7   2024-03-18  ATL @ LAL  22300990            LAL      (LAL, ✅)   (LAL, -9.0, ✅)
# 8   2024-03-18                                             75.0%            75.0%
# 0   2024-03-19  CHA @ ORL  22300991            ORL      (ORL, ✅)  (ORL, -13.0, ✅)
# 1   2024-03-19  HOU @ WAS  22300992            HOU      (HOU, ✅)  (HOU, -10.5, ✅)
# 2   2024-03-19  NOP @ BKN  22300993            NOP      (NOP, ✅)   (NOP, -7.0, ✅)
# 3   2024-03-19  DAL @ SAS  22300994            DAL      (DAL, ✅)   (DAL, -9.0, ✅)
# 4   2024-03-19  DEN @ MIN  22300995            MIN      (DEN, ❌)   (DEN, -8.0, ❌)
# 5   2024-03-19                                             80.0%            80.0%
# 0   2024-03-20  MIA @ CLE  22300996            CLE      (MIA, ❌)   (CLE, -3.0, ✅)
# 1   2024-03-20  IND @ DET  22300997            DET      (IND, ❌)  (IND, -11.0, ❌)
# 2   2024-03-20  MIL @ BOS  22300998            BOS      (BOS, ✅)  (BOS, -10.5, ✅)
# 3   2024-03-20  SAC @ TOR  22300999            SAC      (SAC, ✅)  (SAC, -11.5, ✅)
# 4   2024-03-20  UTA @ OKC  22301000            UTA      (OKC, ❌)  (OKC, -16.0, ❌)
# 5   2024-03-20  MEM @ GSW  22301001            GSW      (GSW, ✅)  (GSW, -11.5, ✅)
# 6   2024-03-20  PHI @ PHX  22301002            PHX      (PHX, ✅)   (PHX, -9.5, ✅)
# 7   2024-03-20  LAC @ POR  22301003            LAC      (LAC, ✅)  (LAC, -12.0, ✅)
# 8   2024-03-20                                             62.5%            75.0%
# 0   2024-03-21  NOP @ ORL  22301004            ORL      (ORL, ✅)   (NOP, -3.0, ❌)
# 1   2024-03-21  SAC @ WAS  22301005            SAC      (WAS, ❌)  (SAC, -11.0, ✅)
# 2   2024-03-21  CHI @ HOU  22301006            HOU      (HOU, ✅)   (HOU, -3.5, ✅)
# 3   2024-03-21  BKN @ MIL  22301007            MIL      (MIL, ✅)  (MIL, -10.5, ✅)
# 4   2024-03-21  UTA @ DAL  22301008            UTA      (DAL, ❌)  (DAL, -14.0, ❌)
# 5   2024-03-21  NYK @ DEN  22301009            NYK      (DEN, ❌)   (DEN, -8.5, ❌)
# 6   2024-03-21  ATL @ PHX  22301010            PHX      (PHX, ✅)   (PHX, -9.5, ✅)
# 7   2024-03-21                                             57.1%            57.1%
# 0   2024-03-22  BOS @ DET  22301011            BOS      (BOS, ✅)  (BOS, -13.5, ✅)
# 1   2024-03-22  OKC @ TOR  22301012            OKC      (OKC, ✅)  (OKC, -16.5, ✅)
# 2   2024-03-22  NOP @ MIA  22301013            NOP      (NOP, ✅)   (MIA, -3.0, ❌)
# 3   2024-03-22  CLE @ MIN  22301014            MIN      (MIN, ✅)   (MIN, -7.5, ✅)
# 4   2024-03-22  MEM @ SAS  22301015            SAS      (MEM, ❌)   (SAS, -6.5, ✅)
# 5   2024-03-22  IND @ GSW  22301016            GSW      (IND, ❌)   (GSW, -4.5, ✅)
# 6   2024-03-22  LAC @ POR  22301017            LAC      (LAC, ✅)  (LAC, -14.5, ✅)
# 7   2024-03-22  PHI @ LAL  22301018            PHI      (LAL, ❌)   (LAL, -7.5, ❌)
# 8   2024-03-22                                             62.5%            75.0%
# 0   2024-03-23  BKN @ NYK  22301019            NYK      (NYK, ✅)   (NYK, -7.5, ✅)
# 1   2024-03-23  SAC @ ORL  22301020            ORL      (SAC, ❌)   (ORL, -3.0, ✅)
# 2   2024-03-23  CHA @ ATL  22301021            ATL      (ATL, ✅)   (ATL, -7.5, ✅)
# 3   2024-03-23  TOR @ WAS  22301022            TOR      (WAS, ❌)   (WAS, -6.0, ❌)
# 4   2024-03-23  BOS @ CHI  22301023            BOS      (BOS, ✅)   (BOS, -5.0, ✅)
# 5   2024-03-23  UTA @ HOU  22301024            HOU      (HOU, ✅)  (HOU, -10.5, ✅)
# 6   2024-03-23  PHX @ SAS  22301025            PHX      (PHX, ✅)  (PHX, -10.0, ✅)
# 7   2024-03-23  DEN @ POR  22301026            DEN      (DEN, ✅)  (DEN, -10.5, ✅)
# 8   2024-03-23                                             75.0%            87.5%
# 0   2024-03-24  NOP @ DET  22301027            NOP      (NOP, ✅)  (NOP, -15.0, ✅)
# 1   2024-03-24  PHI @ LAC  22301028            LAC      (PHI, ❌)   (LAC, -9.0, ✅)
# 2   2024-03-24  CLE @ MIA  22301029            CLE      (MIA, ❌)   (MIA, -3.5, ❌)
# 3   2024-03-24  OKC @ MIL  22301030            MIL      (MIL, ✅)   (MIL, -2.5, ✅)
# 4   2024-03-24  GSW @ MIN  22301031            MIN      (MIN, ✅)   (MIN, -2.5, ✅)
# 5   2024-03-24  IND @ LAL  22301032            LAL      (LAL, ✅)   (LAL, -2.5, ✅)
# 6   2024-03-24                                             66.7%            83.3%
# 0   2024-03-25  CHA @ CLE  22301033            CLE      (CLE, ✅)  (CLE, -10.5, ✅)
# 1   2024-03-25  BOS @ ATL  22301034            BOS      (ATL, ❌)  (BOS, -10.5, ✅)
# 2   2024-03-25  DET @ NYK  22301035            NYK      (NYK, ✅)  (NYK, -17.0, ✅)
# 3   2024-03-25  BKN @ TOR  22301036            BKN      (BKN, ✅)   (BKN, -6.5, ✅)
# 4   2024-03-25  WAS @ CHI  22301037            CHI      (WAS, ❌)  (CHI, -13.5, ✅)
# 5   2024-03-25  POR @ HOU  22301038            HOU      (HOU, ✅)  (HOU, -14.5, ✅)
# 6   2024-03-25  PHX @ SAS  22301039            SAS      (SAS, ✅)  (PHX, -12.0, ❌)
# 7   2024-03-25  MEM @ DEN  22301040            DEN      (DEN, ✅)  (DEN, -12.5, ✅)
# 8   2024-03-25  DAL @ UTA  22301041            DAL      (DAL, ✅)   (DAL, -8.0, ✅)
# 9   2024-03-25  PHI @ SAC  22301042            PHI      (SAC, ❌)   (SAC, -7.5, ❌)
# 10  2024-03-25  IND @ LAC  22301043            LAC      (IND, ❌)   (LAC, -6.0, ✅)
# 11  2024-03-25                                             63.6%            81.8%
# 0   2024-03-26  GSW @ MIA  22301044            MIA      (GSW, ❌)   (GSW, -4.5, ❌)
# 1   2024-03-26  LAL @ MIL  22301045            MIL      (LAL, ❌)   (MIL, -9.5, ✅)
# 2   2024-03-26  OKC @ NOP  22301046            NOP      (OKC, ❌)   (OKC, -1.0, ❌)
# 3   2024-03-26  DAL @ SAC  22301047            SAC      (DAL, ❌)   (SAC, -1.0, ✅)
# 4   2024-03-26                                              0.0%            50.0%
# 0   2024-03-27  CLE @ CHA  22301048            CLE      (CHA, ❌)   (CLE, -9.5, ✅)
# 1   2024-03-27  GSW @ ORL  22301049            ORL      (GSW, ❌)   (ORL, -4.0, ✅)
# 2   2024-03-27  BKN @ WAS  22301050            BKN      (BKN, ✅)   (BKN, -4.0, ✅)
# 3   2024-03-27  POR @ ATL  22301051            POR      (ATL, ❌)  (ATL, -12.0, ❌)
# 4   2024-03-27  LAC @ PHI  22301052            LAC      (LAC, ✅)   (LAC, -6.5, ✅)
# 5   2024-03-27  NYK @ TOR  22301053            NYK      (NYK, ✅)  (NYK, -14.0, ✅)
# 6   2024-03-27  IND @ CHI  22301054            IND      (CHI, ❌)   (IND, -3.0, ✅)
# 7   2024-03-27  LAL @ MEM  22301055            LAL      (LAL, ✅)   (LAL, -4.5, ✅)
# 8   2024-03-27  DET @ MIN  22301056            MIN      (MIN, ✅)  (MIN, -16.5, ✅)
# 9   2024-03-27  HOU @ OKC  22301057            HOU      (HOU, ✅)   (OKC, -5.0, ❌)
# 10  2024-03-27  SAS @ UTA  22301058            SAS      (SAS, ✅)   (UTA, -4.0, ❌)
# 11  2024-03-27  PHX @ DEN  22301059            DEN      (PHX, ❌)   (DEN, -5.5, ✅)
# 12  2024-03-27                                             58.3%            75.0%
# 0   2024-03-28  BOS @ ATL  22301060            BOS      (ATL, ❌)  (BOS, -16.0, ✅)
# 1   2024-03-28  MIL @ NOP  22301061            MIL      (NOP, ❌)   (MIL, -2.0, ✅)
# 2   2024-03-28                                              0.0%           100.0%
# 0   2024-03-29  GSW @ CHA  22301062            GSW      (GSW, ✅)  (GSW, -12.0, ✅)
# 1   2024-03-29  LAL @ IND  22301063            LAL      (IND, ❌)   (IND, -3.5, ❌)
# 2   2024-03-29  LAC @ ORL  22301064            LAC      (LAC, ✅)   (LAC, -1.5, ✅)
# 3   2024-03-29  DET @ WAS  22301065            WAS      (DET, ❌)   (WAS, -3.5, ✅)
# 4   2024-03-29  CHI @ BKN  22301066            CHI      (BKN, ❌)   (CHI, -3.0, ✅)
# 5   2024-03-29  PHI @ CLE  22301067            CLE      (CLE, ✅)   (CLE, -7.0, ✅)
# 6   2024-03-29  POR @ MIA  22301068            MIA      (MIA, ✅)  (MIA, -14.0, ✅)
# 7   2024-03-29  PHX @ OKC  22301069            OKC      (OKC, ✅)   (PHX, -2.5, ❌)
# 8   2024-03-29  NYK @ SAS  22301070            NYK      (SAS, ❌)   (NYK, -8.5, ✅)
# 9   2024-03-29  MIN @ DEN  22301071            DEN      (MIN, ❌)   (DEN, -3.0, ✅)
# 10  2024-03-29  HOU @ UTA  22301072            HOU      (HOU, ✅)   (HOU, -8.5, ✅)
# 11  2024-03-29  DAL @ SAC  22301073            DAL      (DAL, ✅)   (DAL, -1.0, ✅)
# 12  2024-03-29                                             58.3%            83.3%
# 0   2024-03-30  BOS @ NOP  22301074            BOS      (BOS, ✅)   (BOS, -6.0, ✅)
# 1   2024-03-30  MEM @ ORL  22301075            ORL      (ORL, ✅)  (ORL, -13.0, ✅)
# 2   2024-03-30  MIL @ ATL  22301076            ATL      (MIL, ❌)   (MIL, -4.5, ❌)
# 3   2024-03-30                                             66.7%            66.7%
# 0   2024-03-31  CLE @ DEN  22301077            CLE      (DEN, ❌)   (DEN, -4.5, ❌)
# 1   2024-03-31  LAL @ BKN  22301078            LAL      (LAL, ✅)   (LAL, -6.5, ✅)
# 2   2024-03-31  LAC @ CHA  22301079            LAC      (LAC, ✅)  (LAC, -14.0, ✅)
# 3   2024-03-31  PHI @ TOR  22301080            PHI      (PHI, ✅)   (PHI, -9.0, ✅)
# 4   2024-03-31  MIA @ WAS  22301081            MIA      (MIA, ✅)  (MIA, -12.0, ✅)
# 5   2024-03-31  OKC @ NYK  22301082            NYK      (OKC, ❌)   (OKC, -2.0, ❌)
# 6   2024-03-31  DAL @ HOU  22301083            HOU      (DAL, ❌)   (DAL, -4.0, ❌)
# 7   2024-03-31  CHI @ MIN  22301084            MIN      (CHI, ❌)   (MIN, -9.0, ✅)
# 8   2024-03-31  GSW @ SAS  22301085            GSW      (GSW, ✅)  (GSW, -10.5, ✅)
# 9   2024-03-31  UTA @ SAC  22301086            SAC      (SAC, ✅)  (SAC, -13.0, ✅)
# 10  2024-03-31                                             60.0%            70.0%
# 0   2024-04-01  BOS @ CHA  22301087            BOS      (BOS, ✅)  (BOS, -18.5, ✅)
# 1   2024-04-01  MEM @ DET  22301088            DET      (MEM, ❌)   (DET, -3.0, ✅)
# 2   2024-04-01  BKN @ IND  22301089            IND      (IND, ✅)  (IND, -12.5, ✅)
# 3   2024-04-01  POR @ ORL  22301090            ORL      (ORL, ✅)  (ORL, -17.0, ✅)
# 4   2024-04-01  ATL @ CHI  22301091            ATL      (ATL, ✅)   (CHI, -2.0, ❌)
# 5   2024-04-01  PHX @ NOP  22301092            NOP      (PHX, ❌)   (NOP, -1.0, ✅)
# 6   2024-04-01                                             66.7%            83.3%
# 0   2024-04-02  DAL @ GSW  22300589            DAL      (GSW, ❌)   (DAL, -1.0, ✅)
# 1   2024-04-02  OKC @ PHI  22301093            OKC      (PHI, ❌)   (PHI, -3.0, ❌)
# 2   2024-04-02  LAL @ TOR  22301094            LAL      (LAL, ✅)  (LAL, -13.5, ✅)
# 3   2024-04-02  MIL @ WAS  22301095            MIL      (WAS, ❌)  (MIL, -13.0, ✅)
# 4   2024-04-02  NYK @ MIA  22301096            NYK      (MIA, ❌)   (MIA, -2.5, ❌)
# 5   2024-04-02  HOU @ MIN  22301098            MIN      (MIN, ✅)   (MIN, -7.5, ✅)
# 6   2024-04-02  SAS @ DEN  22301099            DEN      (DEN, ✅)  (DEN, -15.5, ✅)
# 7   2024-04-02  CLE @ UTA  22301100            CLE      (CLE, ✅)   (CLE, -9.5, ✅)
# 8   2024-04-02  LAC @ SAC  22301101            SAC      (SAC, ✅)   (SAC, -2.5, ✅)
# 9   2024-04-02                                             55.6%            77.8%
# 0   2024-04-03  POR @ CHA  22301102            POR      (POR, ✅)   (CHA, -1.5, ❌)
# 1   2024-04-03  LAL @ WAS  22301103            LAL      (LAL, ✅)  (LAL, -13.0, ✅)
# 2   2024-04-03  DET @ ATL  22301104            ATL      (ATL, ✅)  (ATL, -12.5, ✅)
# 3   2024-04-03  OKC @ BOS  22301105            BOS      (BOS, ✅)  (BOS, -12.0, ✅)
# 4   2024-04-03  IND @ BKN  22301106            IND      (BKN, ❌)   (IND, -7.0, ✅)
# 5   2024-04-03  MEM @ MIL  22301107            MIL      (MEM, ❌)  (MIL, -12.5, ✅)
# 6   2024-04-03  TOR @ MIN  22301108            MIN      (MIN, ✅)  (MIN, -18.0, ✅)
# 7   2024-04-03  ORL @ NOP  22301109            NOP      (ORL, ❌)   (NOP, -4.5, ✅)
# 8   2024-04-03  CLE @ PHX  22301110            CLE      (PHX, ❌)   (PHX, -6.0, ❌)
# 9   2024-04-03                                             55.6%            77.8%
# 0   2024-04-04  PHI @ MIA  22301111            MIA      (PHI, ❌)   (MIA, -2.5, ✅)
# 1   2024-04-04  SAC @ NYK  22301112            NYK      (NYK, ✅)   (NYK, -4.0, ✅)
# 2   2024-04-04  GSW @ HOU  22301113            HOU      (GSW, ❌)   (GSW, -3.0, ❌)
# 3   2024-04-04  DEN @ LAC  22301114            DEN      (LAC, ❌)   (DEN, -3.5, ✅)
# 4   2024-04-04  ATL @ DAL  22301124            DAL      (DAL, ✅)  (DAL, -12.0, ✅)
# 5   2024-04-04                                             40.0%            80.0%
# 0   2024-04-05  GSW @ DAL  22301097            GSW      (DAL, ❌)   (GSW, -1.0, ✅)
# 1   2024-04-05  ORL @ CHA  22301115            ORL      (CHA, ❌)  (ORL, -12.5, ✅)
# 2   2024-04-05  OKC @ IND  22301116            OKC      (IND, ❌)   (IND, -6.5, ❌)
# 3   2024-04-05  POR @ WAS  22301117            POR      (POR, ✅)   (WAS, -3.0, ❌)
# 4   2024-04-05  SAC @ BOS  22301118            BOS      (BOS, ✅)   (BOS, -9.5, ✅)
# 5   2024-04-05  NYK @ CHI  22301119            NYK      (CHI, ❌)   (NYK, -1.5, ✅)
# 6   2024-04-05  MIA @ HOU  22301120            MIA      (MIA, ✅)   (MIA, -3.0, ✅)
# 7   2024-04-05  DET @ MEM  22301121            MEM      (MEM, ✅)   (DET, -1.0, ❌)
# 8   2024-04-05  TOR @ MIL  22301122            MIL      (TOR, ❌)  (MIL, -14.0, ✅)
# 9   2024-04-05  SAS @ NOP  22301123            SAS      (SAS, ✅)  (NOP, -11.0, ❌)
# 10  2024-04-05  MIN @ PHX  22301125            MIN      (PHX, ❌)   (PHX, -4.5, ❌)
# 11  2024-04-05  UTA @ LAC  22301126            LAC      (LAC, ✅)  (LAC, -12.5, ✅)
# 12  2024-04-05                                             50.0%            58.3%
# 0   2024-04-06  CLE @ LAL  22301127            CLE      (LAL, ❌)   (LAL, -5.0, ❌)
# 1   2024-04-06  DET @ BKN  22301128            BKN      (BKN, ✅)  (BKN, -10.0, ✅)
# 2   2024-04-06  PHI @ MEM  22301129            PHI      (PHI, ✅)  (PHI, -14.5, ✅)
# 3   2024-04-06  ATL @ DEN  22301130            DEN      (DEN, ✅)  (DEN, -10.5, ✅)
# 4   2024-04-06                                             75.0%            75.0%
# 0   2024-04-07  HOU @ DAL  22301131            DAL      (DAL, ✅)   (DAL, -9.0, ✅)
# 1   2024-04-07  CLE @ LAC  22301132            LAC      (LAC, ✅)   (LAC, -4.0, ✅)
# 2   2024-04-07  MIA @ IND  22301133            MIA      (IND, ❌)   (IND, -3.0, ❌)
# 3   2024-04-07  POR @ BOS  22301134            BOS      (BOS, ✅)  (BOS, -17.0, ✅)
# 4   2024-04-07  OKC @ CHA  22301135            OKC      (OKC, ✅)   (OKC, -7.5, ✅)
# 5   2024-04-07  CHI @ ORL  22301136            ORL      (ORL, ✅)   (ORL, -7.0, ✅)
# 6   2024-04-07  WAS @ TOR  22301137            TOR      (TOR, ✅)   (TOR, -5.0, ✅)
# 7   2024-04-07  NOP @ PHX  22301138            PHX      (NOP, ❌)   (PHX, -5.5, ✅)
# 8   2024-04-07  NYK @ MIL  22301139            NYK      (NYK, ✅)   (MIL, -4.5, ❌)
# 9   2024-04-07  PHI @ SAS  22301140            PHI      (PHI, ✅)   (PHI, -3.5, ✅)
# 10  2024-04-07  SAC @ BKN  22301141            SAC      (SAC, ✅)  (SAC, -11.0, ✅)
# 11  2024-04-07  UTA @ GSW  22301142            GSW      (GSW, ✅)  (GSW, -13.0, ✅)
# 12  2024-04-07  MIN @ LAL  22301143            MIN      (MIN, ✅)   (MIN, -2.0, ✅)
# 13  2024-04-07                                             84.6%            84.6%
# 0   2024-04-09  DAL @ CHA  22301144            CHA      (DAL, ❌)  (DAL, -12.5, ❌)
# 1   2024-04-09  DET @ PHI  22301145            PHI      (PHI, ✅)  (PHI, -15.5, ✅)
# 2   2024-04-09  IND @ TOR  22301146            TOR      (IND, ❌)  (IND, -14.0, ❌)
# 3   2024-04-09  MIA @ ATL  22301147            MIA      (MIA, ✅)   (MIA, -3.5, ✅)
# 4   2024-04-09  BOS @ MIL  22301148            BOS      (MIL, ❌)   (MIL, -3.5, ❌)
# 5   2024-04-09  NYK @ CHI  22301149            CHI      (NYK, ❌)   (NYK, -5.0, ❌)
# 6   2024-04-09  ORL @ HOU  22301150            ORL      (HOU, ❌)   (ORL, -2.5, ✅)
# 7   2024-04-09  SAS @ MEM  22301151            SAS      (SAS, ✅)   (SAS, -5.5, ✅)
# 8   2024-04-09  WAS @ MIN  22301152            MIN      (MIN, ✅)  (MIN, -18.0, ✅)
# 9   2024-04-09  SAC @ OKC  22301153            OKC      (OKC, ✅)   (OKC, -5.5, ✅)
# 10  2024-04-09  DEN @ UTA  22301154            DEN      (DEN, ✅)  (DEN, -15.5, ✅)
# 11  2024-04-09  GSW @ LAL  22301155            LAL      (GSW, ❌)   (GSW, -2.0, ❌)
# 12  2024-04-09  LAC @ PHX  22301156            LAC      (LAC, ✅)   (PHX, -9.5, ❌)
# 13  2024-04-09  NOP @ POR  22301157            NOP      (NOP, ✅)  (NOP, -14.0, ✅)
# 14  2024-04-09                                             57.1%            57.1%
# 0   2024-04-10  MEM @ CLE  22301158            CLE      (CLE, ✅)  (CLE, -18.5, ✅)
# 1   2024-04-10  CHA @ ATL  22301159            ATL      (CHA, ❌)   (ATL, -8.5, ✅)
# 2   2024-04-10  TOR @ BKN  22301160            TOR      (BKN, ❌)  (BKN, -12.0, ❌)
# 3   2024-04-10  DAL @ MIA  22301161            DAL      (DAL, ✅)   (DAL, -3.0, ✅)
# 4   2024-04-10  ORL @ MIL  22301162            ORL      (MIL, ❌)   (ORL, -2.0, ✅)
# 5   2024-04-10  SAS @ OKC  22301163            OKC      (OKC, ✅)  (OKC, -17.0, ✅)
# 6   2024-04-10  MIN @ DEN  22301164            MIN      (DEN, ❌)   (DEN, -7.5, ❌)
# 7   2024-04-10  PHX @ LAC  22301165            LAC      (PHX, ❌)  (PHX, -12.0, ❌)
# 8   2024-04-10                                             37.5%            62.5%
# 0   2024-04-11  CHI @ DET  22301166            CHI      (CHI, ✅)  (CHI, -11.0, ✅)
# 1   2024-04-11  NYK @ BOS  22301167            BOS      (NYK, ❌)   (BOS, -3.5, ✅)
# 2   2024-04-11  HOU @ UTA  22301168            HOU      (UTA, ❌)  (HOU, -11.5, ✅)
# 3   2024-04-11  GSW @ POR  22301169            GSW      (GSW, ✅)  (GSW, -13.5, ✅)
# 4   2024-04-11  NOP @ SAC  22301170            SAC      (NOP, ❌)   (SAC, -1.5, ✅)
# 5   2024-04-11                                             40.0%           100.0%
# 0   2024-04-12  ORL @ PHI  22301171            ORL      (PHI, ❌)   (PHI, -6.5, ❌)
# 1   2024-04-12  CHI @ WAS  22301172            CHI      (CHI, ✅)   (WAS, -1.5, ❌)
# 2   2024-04-12  CHA @ BOS  22301173            BOS      (BOS, ✅)   (BOS, -7.5, ✅)
# 3   2024-04-12  IND @ CLE  22301174            IND      (CLE, ❌)   (CLE, -3.0, ❌)
# 4   2024-04-12  BKN @ NYK  22301175            NYK      (NYK, ✅)  (NYK, -11.5, ✅)
# 5   2024-04-12  TOR @ MIA  22301176            TOR      (MIA, ❌)  (MIA, -14.0, ❌)
# 6   2024-04-12  LAL @ MEM  22301177            LAL      (LAL, ✅)  (LAL, -16.0, ✅)
# 7   2024-04-12  ATL @ MIN  22301178            MIN      (MIN, ✅)  (MIN, -12.5, ✅)
# 8   2024-04-12  MIL @ OKC  22301179            MIL      (OKC, ❌)  (OKC, -14.0, ❌)
# 9   2024-04-12  DEN @ SAS  22301180            DEN      (SAS, ❌)  (DEN, -11.5, ✅)
# 10  2024-04-12  DET @ DAL  22301181            DAL      (DET, ❌)  (DAL, -11.0, ✅)
# 11  2024-04-12  NOP @ GSW  22301182            GSW      (NOP, ❌)   (GSW, -4.0, ✅)
# 12  2024-04-12  HOU @ POR  22301183            HOU      (HOU, ✅)   (HOU, -6.0, ✅)
# 13  2024-04-12  UTA @ LAC  22301184            LAC      (UTA, ❌)  (LAC, -15.5, ✅)
# 14  2024-04-12  PHX @ SAC  22301185            SAC      (PHX, ❌)   (PHX, -4.5, ❌)
# 15  2024-04-12                                             40.0%            60.0%
# 0   2024-04-14  WAS @ BOS  22301186            BOS      (BOS, ✅)  (BOS, -10.0, ✅)
# 1   2024-04-14  CHA @ CLE  22301187            CLE      (CHA, ❌)  (CLE, -14.5, ✅)
# 2   2024-04-14  ATL @ IND  22301188            IND      (IND, ✅)  (IND, -14.0, ✅)
# 3   2024-04-14  TOR @ MIA  22301189            MIA      (MIA, ✅)  (MIA, -16.5, ✅)
# 4   2024-04-14  CHI @ NYK  22301190            NYK      (NYK, ✅)  (NYK, -13.5, ✅)
# 5   2024-04-14  MIL @ ORL  22301191            ORL      (ORL, ✅)   (ORL, -6.0, ✅)
# 6   2024-04-14  BKN @ PHI  22301192            PHI      (PHI, ✅)  (PHI, -13.0, ✅)
# 7   2024-04-14  DEN @ MEM  22301193            DEN      (DEN, ✅)  (DEN, -14.0, ✅)
# 8   2024-04-14  PHX @ MIN  22301194            MIN      (PHX, ❌)   (MIN, -2.0, ✅)
# 9   2024-04-14  LAL @ NOP  22301195            NOP      (LAL, ❌)   (NOP, -2.0, ✅)
# 10  2024-04-14  DAL @ OKC  22301196            DAL      (OKC, ❌)  (OKC, -19.5, ❌)
# 11  2024-04-14  DET @ SAS  22301197            SAS      (SAS, ✅)   (SAS, -4.5, ✅)
# 12  2024-04-14  UTA @ GSW  22301198            GSW      (GSW, ✅)  (GSW, -11.0, ✅)
# 13  2024-04-14  HOU @ LAC  22301199            LAC      (HOU, ❌)   (HOU, -4.0, ❌)
# 14  2024-04-14  POR @ SAC  22301200            SAC      (SAC, ✅)  (SAC, -17.5, ✅)
# 15  2024-04-14                                             66.7%            86.7%

# %%
# for key in traditionalMatchResults.keys():
#     print(len(traditionalMatchResults[key]))

# %%
count = 0
for boxScore in boxScoreTypes:
    for team in pd.concat(getModelPredictions(boxScore))['MODEL PREDICTS'].values:
        if team in NBATeams:
            count = count + 1
print(count)
# Out:
# 2046

# %%
getActualAccuracy(pd.concat(getModelPredictions(traditionalMatchResults)))
# Out:
# 409
# '57.7%'

# %%
#traditionalMatchResults

# %%
boxScoreTypes = ['TRADITIONAL','ADVANCED','FOUR FACTORS','MISC','SCORING']
modelAccuracies = pd.concat([pd.DataFrame(actualAccuracies,columns=['ACTUAL ACCURACY']),
                             pd.DataFrame(bettingFavoriteAccuracies,columns=['BETTING FAVORITE ACCURACY'])],axis=1)

modelAccuracies = pd.concat([pd.DataFrame(boxScoreTypes,columns=['BOX SCORE']),
                            modelAccuracies],axis=1)

# %%
print(modelAccuracies.sort_values(by=['ACTUAL ACCURACY'],ascending=False).reset_index(drop=True))
# Out:
#       BOX SCORE ACTUAL ACCURACY BETTING FAVORITE ACCURACY
# 0       SCORING           62.4%                     72.4%
# 1      ADVANCED           62.0%                     70.0%
# 2          MISC           60.4%                     66.5%
# 3   TRADITIONAL           57.7%                     70.9%
# 4  FOUR FACTORS           55.4%                     66.7%

# %%
print(modelAccuracies.sort_values(by=['BETTING FAVORITE ACCURACY'],ascending=False).reset_index(drop=True))
# Out:
#       BOX SCORE ACTUAL ACCURACY BETTING FAVORITE ACCURACY
# 0       SCORING           62.4%                     72.4%
# 1   TRADITIONAL           57.7%                     70.9%
# 2      ADVANCED           62.0%                     70.0%
# 3  FOUR FACTORS           55.4%                     66.7%
# 4          MISC           60.4%                     66.5%

# %%
def getGini(y):
    classProbabilitiesSquared = []
    possibleOutcomes = len(y)
    for classCount in np.unique(y,return_counts=True)[1]: #edge case
        classProbabilitiesSquared.append(((classCount/possibleOutcomes)**2))
    gini = (1 - sum(classProbabilitiesSquared))
    return gini
def getDepth1Split(NBAdf,features,team,date):
    #NBAtrain = NBAdf[NBAdf['DATE'] < date].dropna()
    NBAtrain = NBAdf[(NBAdf['DATE'] < date) & (NBAdf['GP'] > 5)]
    NBAtrain = NBAtrain[NBAtrain['TEAM'] == team]
    X_trainDF = pd.DataFrame()
    for feature in features:
        X_trainDF = pd.concat([X_trainDF,NBAtrain[feature]],axis=1)
    y_trainDF = NBAtrain['RESULT']
    #return getSplitOptions(team,X_trainDF,y_trainDF,datesPostAllStarGame[0])[0]
    return getSplitOptions(team,X_trainDF,y_trainDF,date)
def getSplitOptions(team,X_trainDF,y_trainDF,date):
    teamDF = pd.concat([X_trainDF,y_trainDF],axis=1)
    splitDict = {}
    splitDict[date] = {}
    splitOptions = []
    index = 0
    for feature in X_trainDF:
        splitDict[date][feature] = {'splitOptions':[]}
        for i in range (len(np.unique(X_trainDF[feature]))-1): #without i?
            splitDict[date][feature]['splitOptions'].append((np.unique(X_trainDF[feature])[i]+
                                                             np.unique(X_trainDF[feature])[i+1])/2)
        for splitOption in splitDict[date][feature]['splitOptions']:
            splitDict[date][feature][splitOption] = {}
            LHS = teamDF[teamDF[feature] <= splitOption]
            RHS = teamDF[teamDF[feature] > splitOption]

            splitDict[date][feature][splitOption]['ROOT GINI'] = getGini(teamDF['RESULT'])
            splitDict[date][feature][splitOption]['ROOT SAMPLES'] = len(LHS)+len(RHS)
            splitDict[date][feature][splitOption]['LHS'] = len(LHS)
            splitDict[date][feature][splitOption]['RHS'] = len(RHS)
            WGI = getGini(LHS['RESULT'])*(len(LHS)/len(teamDF))+getGini(RHS['RESULT'])*(len(RHS)/len(teamDF))
            splitDict[date][feature][splitOption]['LHS GINI'] = getGini(LHS['RESULT'])
            splitDict[date][feature][splitOption]['RHS GINI'] = getGini(RHS['RESULT'])
            splitDict[date][feature][splitOption]['WGI'] = WGI
            splitOptions.append ([('INDEX',index),('DATE',date),
                                  ('TEAM',team),('FEATURE',feature),
                                  ('SPLIT OPTION',splitOption),
                                  ('ROOT GINI',getGini(teamDF['RESULT'])),
                                  ('ROOT SAMPLES',len(LHS)+len(RHS)),
                                  ('LHS',len(LHS)),('RHS',len(RHS)),
                                  ('LHS GINI',getGini(LHS['RESULT'])),
                                  ('RHS GINI',getGini(RHS['RESULT'])),
                                  ('WGI', WGI)])
            index=index+1
    return splitOptions
#     WGI_index = splitOptions[0].index(splitOptions[0][-1])
#     return sorted(splitOptions, key=lambda x:x[WGI_index])

# %% [markdown]
# # EXCERPT FROM ACCURACY RESULTS:

# %% [markdown]
# #### 2024-02-22 results, predictions made by model that reports the best accuracy of all games predicted (72.4%)

# %%
scoringMatchResults[datetime.date(2024, 2, 22)]
# Out:
#           DATE      MATCH    GAMEID MODEL PREDICTS ACTUAL WINNER BETTING FAVORITE
# 0   2024-02-22  ORL @ CLE  22300792            CLE      (ORL, ❌)   (CLE, -5.0, ✅)
# 1   2024-02-22  DET @ IND  22300793            IND      (IND, ✅)  (IND, -12.0, ✅)
# 2   2024-02-22  NYK @ PHI  22300794            NYK      (NYK, ✅)   (PHI, -1.5, ❌)
# 3   2024-02-22  BKN @ TOR  22300795            TOR      (TOR, ✅)   (TOR, -1.5, ✅)
# 4   2024-02-22  PHX @ DAL  22300796            PHX      (DAL, ❌)   (DAL, -2.5, ❌)
# 5   2024-02-22  BOS @ CHI  22300797            BOS      (BOS, ✅)   (BOS, -8.5, ✅)
# 6   2024-02-22  HOU @ NOP  22300798            NOP      (NOP, ✅)   (NOP, -6.5, ✅)
# 7   2024-02-22  LAC @ OKC  22300799            OKC      (OKC, ✅)   (OKC, -1.5, ✅)
# 8   2024-02-22  WAS @ DEN  22300800            DEN      (DEN, ✅)  (DEN, -15.5, ✅)
# 9   2024-02-22  CHA @ UTA  22300801            UTA      (CHA, ❌)   (UTA, -9.5, ✅)
# 10  2024-02-22  LAL @ GSW  22300802            GSW      (GSW, ✅)   (GSW, -6.0, ✅)
# 11  2024-02-22  SAS @ SAC  22300803            SAC      (SAC, ✅)  (SAC, -10.5, ✅)
# 12  2024-02-22                                             75.0%            83.3%

# %%
pd.DataFrame(scoringTestDetails[datetime.date(2024, 2, 22)]).T.reset_index(drop=False).rename(columns=({'index':'TEAM'}))
# Out:
#    TEAM        DATE    GAMEID TRAIN SIZE                     SPLIT DETAILS                          X_test FINAL NODE DETAILS PROBABILITY ESTIMATE  \
# 0   ORL  2024-02-22  22300792         50    {0: ('FGM %UASTL3MA', 43.133)}    [(FGM %UASTL3MA, 40.367, T)]    (1, 16.0, 27.0)             0.627907
# 1   CLE  2024-02-22  22300792         48   {0: ('%PTS OFF TOL5MA', 18.18)}   [(%PTS OFF TOL5MA, 15.58, T)]    (1, 11.0, 34.0)             0.755556
# 2   DET  2024-02-22  22300793         49    {0: ('%PTS OFF TOL3MA', 10.1)}  [(%PTS OFF TOL3MA, 20.967, F)]     (2, 34.0, 0.0)                  0.0
# 3   IND  2024-02-22  22300793         51     {0: ('%PTS 2PT MRL1MA', 3.6)}     [(%PTS 2PT MRL1MA, 4.7, F)]    (2, 23.0, 19.0)             0.452381
# 4   NYK  2024-02-22  22300794         50      {0: ('%PTS 2PTL5MA', 54.86)}       [(%PTS 2PTL5MA, 54.5, T)]    (1, 12.0, 31.0)              0.72093
# 5   PHI  2024-02-22  22300794         49      {0: ('%PTS 2PTL2MA', 59.45)}       [(%PTS 2PTL2MA, 59.9, F)]      (2, 7.0, 0.0)                  0.0
# 6   BKN  2024-02-22  22300795         49     {0: ('2FGM %UASTL5MA', 53.3)}     [(2FGM %UASTL5MA, 35.2, T)]    (1, 30.0, 11.0)             0.268293
# 7   TOR  2024-02-22  22300795         50   {0: ('%PTS OFF TOL2MA', 16.55)}    [(%PTS OFF TOL2MA, 11.6, T)]    (1, 20.0, 17.0)             0.459459
# 8   PHX  2024-02-22  22300796         50      {0: ('%PTS FTL4MA', 18.887)}        [(%PTS FTL4MA, 18.8, T)]    (1, 10.0, 27.0)              0.72973
# 9   DAL  2024-02-22  22300796         50      {0: ('3FGM %ASTL1MA', 71.0)}      [(3FGM %ASTL1MA, 81.8, F)]    (2, 10.0, 24.0)             0.705882
# 10  BOS  2024-02-22  22300797         50    {0: ('FGM %UASTL3MA', 44.367)}      [(FGM %UASTL3MA, 33.5, T)]     (1, 6.0, 35.0)             0.853659
# 11  CHI  2024-02-22  22300797         50      {0: ('%PTS FBPSL3MA', 11.5)}     [(%PTS FBPSL3MA, 7.033, T)]     (1, 18.0, 6.0)                 0.25
# 12  HOU  2024-02-22  22300798         49      {0: ('%PTS 3PTL2MA', 32.15)}       [(%PTS 3PTL2MA, 28.9, T)]     (1, 21.0, 4.0)                 0.16
# 13  NOP  2024-02-22  22300798         50      {0: ('%FGA 3PTL4MA', 38.85)}      [(%FGA 3PTL4MA, 37.25, T)]    (1, 14.0, 28.0)             0.666667
# 14  LAC  2024-02-22  22300799         48     {0: ('2FGM %UASTL5MA', 50.0)}    [(2FGM %UASTL5MA, 43.42, T)]    (1, 10.0, 33.0)             0.767442
# 15  OKC  2024-02-22  22300799         49     {0: ('%FGA 2PTL2MA', 58.775)}      [(%FGA 2PTL2MA, 65.05, F)]     (2, 7.0, 30.0)             0.810811
# 16  WAS  2024-02-22  22300800         49   {0: ('2FGM %UASTL3MA', 33.283)}   [(2FGM %UASTL3MA, 38.033, F)]     (2, 40.0, 5.0)             0.111111
# 17  DEN  2024-02-22  22300800         50    {0: ('FGM %UASTL3MA', 34.283)}    [(FGM %UASTL3MA, 29.267, T)]    (1, 14.0, 10.0)             0.416667
# 18  CHA  2024-02-22  22300801         49  {0: ('%PTS OFF TOL3MA', 11.733)}  [(%PTS OFF TOL3MA, 12.033, F)]     (2, 35.0, 5.0)                0.125
# 19  UTA  2024-02-22  22300801         51      {0: ('%PTS 3PTL5MA', 30.56)}      [(%PTS 3PTL5MA, 35.72, F)]    (2, 27.0, 16.0)             0.372093
# 20  LAL  2024-02-22  22300802         51      {0: ('%FGA 2PTL1MA', 61.65)}       [(%FGA 2PTL1MA, 65.9, F)]    (2, 12.0, 24.0)             0.666667
# 21  GSW  2024-02-22  22300802         48     {0: ('%PTS 3PTL3MA', 38.533)}       [(%PTS 3PTL3MA, 44.2, F)]     (2, 4.0, 15.0)             0.789474
# 22  SAS  2024-02-22  22300803         50     {0: ('FGM %ASTL2MA', 63.675)}       [(FGM %ASTL2MA, 80.5, F)]     (2, 40.0, 4.0)             0.090909
# 23  SAC  2024-02-22  22300803         49     {0: ('3FGM %ASTL5MA', 88.85)}     [(3FGM %ASTL5MA, 87.24, T)]     (1, 7.0, 24.0)             0.774194
#
#    ACTUAL RESULT SPREAD
# 0              1    5.0
# 1              0   -5.0
# 2              0   12.0
# 3              1  -12.0
# 4              1    1.5
# 5              0   -1.5
# 6              0    1.5
# 7              1   -1.5
# 8              0    2.5
# 9              1   -2.5
# 10             1   -8.5
# 11             0    8.5
# 12             0    6.5
# 13             1   -6.5
# 14             0    1.5
# 15             1   -1.5
# 16             0   15.5
# 17             1  -15.5
# 18             1    9.5
# 19             0   -9.5
# 20             0    6.0
# 21             1   -6.0
# 22             0   10.5
# 23             1  -10.5

# %%
def printFeatureDefintion(feature):
    import textwrap
    subStringsToRemove = ['L1MA','L2MA','L3MA','L4MA','L5MA']
    for subString in subStringsToRemove:
        feature = feature.replace(subString, '')
    definiton = glossaryDict[feature]['Name']+': '+glossaryDict[feature]['Definition']
    print(textwrap.fill(definiton,30))
    
def getImage(path, zoom=1): return OffsetImage(plt.imread(path), zoom=zoom)
    
    
# def getFeatureDefintionWrapped(feature):
#     import textwrap
#     subStringsToRemove = ['L1MA','L2MA','L3MA','L4MA','L5MA']
#     for subString in subStringsToRemove:
#         feature = feature.replace(subString, '')
#     definition = glossaryDict[feature]['Name']+': '+glossaryDict[feature]['Definition']
#     #return definition
#     return textwrap.fill(definition,40)

def getFeatureDefintion(feature):
    import textwrap
    subStringsToRemove = ['L1MA','L2MA','L3MA','L4MA','L5MA']
    for subString in subStringsToRemove:
        feature = feature.replace(subString, '')
    definition = glossaryDict[feature]['Name']+': '+glossaryDict[feature]['Definition']
    return definition

def plotTrees(NBAdf,awayTeam,homeTeam,date,maxDepth):
    NBAtrain = NBAdf[NBAdf['DATE'] < date].dropna()
    models = []
    featureNames = []
    matchup = [awayTeam,homeTeam]
    for tuple_ in matchup:
        team = tuple_[0]
        features = []
        for featureIter in range(1,len(tuple_)):
            features.append(tuple_[featureIter])
        X_trainDF = pd.DataFrame()
        for feature in features: X_trainDF = pd.concat([X_trainDF,NBAtrain[NBAtrain['TEAM'] == team][feature]],axis=1)     
        y_trainDF = NBAtrain[NBAtrain['TEAM'] == team]['RESULT']
        model = DecisionTreeClassifier(random_state=0,max_depth=maxDepth)
        model.fit(X_trainDF,y_trainDF)
        models.append(model)
        featureNames.append(features)
    fig,axes = plt.subplots(nrows=1,ncols=2,figsize=(15,7))
    ax0,ax1 = axes.flatten()

    tree.plot_tree(models[0],fontsize=15,node_ids=True,filled=True,rounded=True,
                   feature_names=featureNames[0],class_names=['0','1'],ax=ax0)
    
    tree.plot_tree(models[1],fontsize=15,node_ids=True,filled=True,rounded=True,
                   feature_names=featureNames[1],class_names=['0','1'],ax=ax1)
    
    path = '/Users/olutosinfashusi/jupyter/git/predict2023-24NBARegularSeasonGames/images/'+awayTeam[0]+'.png'
    ab = AnnotationBbox(getImage(path),(.5,1), frameon=False)
    ax0.add_artist(ab)
    path = '/Users/olutosinfashusi/jupyter/git/predict2023-24NBARegularSeasonGames/images/'+homeTeam[0]+'.png'
    ab = AnnotationBbox(getImage(path),(.5,1), frameon=False)
    ax1.add_artist(ab)
    
    
    defintion = getFeatureDefintionWrapped(awayTeam[1])
    ax0.set_xlabel(defintion,loc='left',fontweight ='bold',size=15)
    
    defintion = getFeatureDefintionWrapped(homeTeam[1])
    ax1.set_xlabel(defintion,loc='left',fontweight ='bold',size=15)
    
    ax0.set_axis_on()
    ax1.set_axis_on()
    ax0.set_frame_on(False)
    ax1.set_frame_on(False)
    ax0.set_xticks(([]))
    ax1.set_xticks(([]))
    ax0.set_yticks(([]))
    ax1.set_yticks(([]))
    plt.show()
    
def plotTree(NBAdf,team,feature,date,maxDepth):
    fig,axes = plt.subplots(nrows=1,ncols=2,figsize=(15,7))
    ax0,ax1 = axes.flatten()
    #plt.figure(figsize=(15,7))
    NBAtrain = NBAdf[NBAdf['DATE'] < date].dropna()
    X_trainDF = pd.DataFrame()
    X_trainDF = pd.concat([X_trainDF,NBAtrain[NBAtrain['TEAM'] == team][feature]],axis=1)     
    y_trainDF = NBAtrain[NBAtrain['TEAM'] == team]['RESULT']
    model = DecisionTreeClassifier(random_state=0,max_depth=maxDepth)
    model.fit(X_trainDF,y_trainDF)
    tree.plot_tree(model,fontsize=15,node_ids=True,filled=True,rounded=True,
                   feature_names=[feature],class_names=['0','1'],ax=ax0)
    path = '/Users/olutosinfashusi/jupyter/git/predict2023-24NBARegularSeasonGames/images/'+team+'.png'
    ab = AnnotationBbox(getImage(path),(.5,1), frameon=False)
    ax0.add_artist(ab)
    defintion = getFeatureDefintionWrapped(feature)
    
    ax0.set_ylabel('DATE: '+str(date),fontweight ='bold',size=20)
    ax0.set_xlabel(defintion,loc='left',fontweight ='bold',size=15)
    
       
    ax0.set_axis_on()
    ax1.set_axis_on()
    ax0.set_frame_on(False)
    ax1.set_frame_on(False)
    ax0.set_xticks(([]))
    ax1.set_xticks(([]))
    ax0.set_yticks(([]))
    ax1.set_yticks(([]))
    plt.show()

# %%
testDetailsDF = pd.DataFrame(scoringTestDetails[datetime.date(2024, 2, 22)]).T
testDetailsDF = testDetailsDF.reset_index(drop=False)
testDetailsDF = testDetailsDF.rename(columns={'index':'TEAM'})
testDetailsDF
# Out:
#    TEAM        DATE    GAMEID TRAIN SIZE                     SPLIT DETAILS                          X_test FINAL NODE DETAILS PROBABILITY ESTIMATE  \
# 0   ORL  2024-02-22  22300792         50    {0: ('FGM %UASTL3MA', 43.133)}    [(FGM %UASTL3MA, 40.367, T)]    (1, 16.0, 27.0)             0.627907
# 1   CLE  2024-02-22  22300792         48   {0: ('%PTS OFF TOL5MA', 18.18)}   [(%PTS OFF TOL5MA, 15.58, T)]    (1, 11.0, 34.0)             0.755556
# 2   DET  2024-02-22  22300793         49    {0: ('%PTS OFF TOL3MA', 10.1)}  [(%PTS OFF TOL3MA, 20.967, F)]     (2, 34.0, 0.0)                  0.0
# 3   IND  2024-02-22  22300793         51     {0: ('%PTS 2PT MRL1MA', 3.6)}     [(%PTS 2PT MRL1MA, 4.7, F)]    (2, 23.0, 19.0)             0.452381
# 4   NYK  2024-02-22  22300794         50      {0: ('%PTS 2PTL5MA', 54.86)}       [(%PTS 2PTL5MA, 54.5, T)]    (1, 12.0, 31.0)              0.72093
# 5   PHI  2024-02-22  22300794         49      {0: ('%PTS 2PTL2MA', 59.45)}       [(%PTS 2PTL2MA, 59.9, F)]      (2, 7.0, 0.0)                  0.0
# 6   BKN  2024-02-22  22300795         49     {0: ('2FGM %UASTL5MA', 53.3)}     [(2FGM %UASTL5MA, 35.2, T)]    (1, 30.0, 11.0)             0.268293
# 7   TOR  2024-02-22  22300795         50   {0: ('%PTS OFF TOL2MA', 16.55)}    [(%PTS OFF TOL2MA, 11.6, T)]    (1, 20.0, 17.0)             0.459459
# 8   PHX  2024-02-22  22300796         50      {0: ('%PTS FTL4MA', 18.887)}        [(%PTS FTL4MA, 18.8, T)]    (1, 10.0, 27.0)              0.72973
# 9   DAL  2024-02-22  22300796         50      {0: ('3FGM %ASTL1MA', 71.0)}      [(3FGM %ASTL1MA, 81.8, F)]    (2, 10.0, 24.0)             0.705882
# 10  BOS  2024-02-22  22300797         50    {0: ('FGM %UASTL3MA', 44.367)}      [(FGM %UASTL3MA, 33.5, T)]     (1, 6.0, 35.0)             0.853659
# 11  CHI  2024-02-22  22300797         50      {0: ('%PTS FBPSL3MA', 11.5)}     [(%PTS FBPSL3MA, 7.033, T)]     (1, 18.0, 6.0)                 0.25
# 12  HOU  2024-02-22  22300798         49      {0: ('%PTS 3PTL2MA', 32.15)}       [(%PTS 3PTL2MA, 28.9, T)]     (1, 21.0, 4.0)                 0.16
# 13  NOP  2024-02-22  22300798         50      {0: ('%FGA 3PTL4MA', 38.85)}      [(%FGA 3PTL4MA, 37.25, T)]    (1, 14.0, 28.0)             0.666667
# 14  LAC  2024-02-22  22300799         48     {0: ('2FGM %UASTL5MA', 50.0)}    [(2FGM %UASTL5MA, 43.42, T)]    (1, 10.0, 33.0)             0.767442
# 15  OKC  2024-02-22  22300799         49     {0: ('%FGA 2PTL2MA', 58.775)}      [(%FGA 2PTL2MA, 65.05, F)]     (2, 7.0, 30.0)             0.810811
# 16  WAS  2024-02-22  22300800         49   {0: ('2FGM %UASTL3MA', 33.283)}   [(2FGM %UASTL3MA, 38.033, F)]     (2, 40.0, 5.0)             0.111111
# 17  DEN  2024-02-22  22300800         50    {0: ('FGM %UASTL3MA', 34.283)}    [(FGM %UASTL3MA, 29.267, T)]    (1, 14.0, 10.0)             0.416667
# 18  CHA  2024-02-22  22300801         49  {0: ('%PTS OFF TOL3MA', 11.733)}  [(%PTS OFF TOL3MA, 12.033, F)]     (2, 35.0, 5.0)                0.125
# 19  UTA  2024-02-22  22300801         51      {0: ('%PTS 3PTL5MA', 30.56)}      [(%PTS 3PTL5MA, 35.72, F)]    (2, 27.0, 16.0)             0.372093
# 20  LAL  2024-02-22  22300802         51      {0: ('%FGA 2PTL1MA', 61.65)}       [(%FGA 2PTL1MA, 65.9, F)]    (2, 12.0, 24.0)             0.666667
# 21  GSW  2024-02-22  22300802         48     {0: ('%PTS 3PTL3MA', 38.533)}       [(%PTS 3PTL3MA, 44.2, F)]     (2, 4.0, 15.0)             0.789474
# 22  SAS  2024-02-22  22300803         50     {0: ('FGM %ASTL2MA', 63.675)}       [(FGM %ASTL2MA, 80.5, F)]     (2, 40.0, 4.0)             0.090909
# 23  SAC  2024-02-22  22300803         49     {0: ('3FGM %ASTL5MA', 88.85)}     [(3FGM %ASTL5MA, 87.24, T)]     (1, 7.0, 24.0)             0.774194
#
#    ACTUAL RESULT SPREAD
# 0              1    5.0
# 1              0   -5.0
# 2              0   12.0
# 3              1  -12.0
# 4              1    1.5
# 5              0   -1.5
# 6              0    1.5
# 7              1   -1.5
# 8              0    2.5
# 9              1   -2.5
# 10             1   -8.5
# 11             0    8.5
# 12             0    6.5
# 13             1   -6.5
# 14             0    1.5
# 15             1   -1.5
# 16             0   15.5
# 17             1  -15.5
# 18             1    9.5
# 19             0   -9.5
# 20             0    6.0
# 21             1   -6.0
# 22             0   10.5
# 23             1  -10.5

# %%
index = [0,1]
plotTrees(scoringDF,
          (testDetailsDF.iloc[index[0]]['TEAM'],testDetailsDF.iloc[index[0]]['SPLIT DETAILS'][0][0]),
          (testDetailsDF.iloc[index[1]]['TEAM'],testDetailsDF.iloc[index[1]]['SPLIT DETAILS'][0][0]),
          datetime.date(2024, 2, 22),1)

# %%
index = [2,3]
plotTrees(scoringDF,
          (testDetailsDF.iloc[index[0]]['TEAM'],testDetailsDF.iloc[index[0]]['SPLIT DETAILS'][0][0]),
          (testDetailsDF.iloc[index[1]]['TEAM'],testDetailsDF.iloc[index[1]]['SPLIT DETAILS'][0][0]),
          datetime.date(2024, 2, 22),1)

# %%
index = [4,5]
plotTrees(scoringDF,
          (testDetailsDF.iloc[index[0]]['TEAM'],testDetailsDF.iloc[index[0]]['SPLIT DETAILS'][0][0]),
          (testDetailsDF.iloc[index[1]]['TEAM'],testDetailsDF.iloc[index[1]]['SPLIT DETAILS'][0][0]),
          datetime.date(2024, 2, 22),1)

# %%
index = [6,7]
plotTrees(scoringDF,
          (testDetailsDF.iloc[index[0]]['TEAM'],testDetailsDF.iloc[index[0]]['SPLIT DETAILS'][0][0]),
          (testDetailsDF.iloc[index[1]]['TEAM'],testDetailsDF.iloc[index[1]]['SPLIT DETAILS'][0][0]),
          datetime.date(2024, 2, 22),1)

# %%
index = [8,9]
plotTrees(scoringDF,
          (testDetailsDF.iloc[index[0]]['TEAM'],testDetailsDF.iloc[index[0]]['SPLIT DETAILS'][0][0]),
          (testDetailsDF.iloc[index[1]]['TEAM'],testDetailsDF.iloc[index[1]]['SPLIT DETAILS'][0][0]),
          datetime.date(2024, 2, 22),1)

# %%
index = [10,11]
plotTrees(scoringDF,
          (testDetailsDF.iloc[index[0]]['TEAM'],testDetailsDF.iloc[index[0]]['SPLIT DETAILS'][0][0]),
          (testDetailsDF.iloc[index[1]]['TEAM'],testDetailsDF.iloc[index[1]]['SPLIT DETAILS'][0][0]),
          datetime.date(2024, 2, 22),1)

# %%
index = [12,13]
plotTrees(scoringDF,
          (testDetailsDF.iloc[index[0]]['TEAM'],testDetailsDF.iloc[index[0]]['SPLIT DETAILS'][0][0]),
          (testDetailsDF.iloc[index[1]]['TEAM'],testDetailsDF.iloc[index[1]]['SPLIT DETAILS'][0][0]),
          datetime.date(2024, 2, 22),1)

# %%
index = [14,15]
plotTrees(scoringDF,
          (testDetailsDF.iloc[index[0]]['TEAM'],testDetailsDF.iloc[index[0]]['SPLIT DETAILS'][0][0]),
          (testDetailsDF.iloc[index[1]]['TEAM'],testDetailsDF.iloc[index[1]]['SPLIT DETAILS'][0][0]),
          datetime.date(2024, 2, 22),1)

# %%
index = [16,17]
plotTrees(scoringDF,
          (testDetailsDF.iloc[index[0]]['TEAM'],testDetailsDF.iloc[index[0]]['SPLIT DETAILS'][0][0]),
          (testDetailsDF.iloc[index[1]]['TEAM'],testDetailsDF.iloc[index[1]]['SPLIT DETAILS'][0][0]),
          datetime.date(2024, 2, 22),1)

# %%
index = [18,19]
plotTrees(scoringDF,
          (testDetailsDF.iloc[index[0]]['TEAM'],testDetailsDF.iloc[index[0]]['SPLIT DETAILS'][0][0]),
          (testDetailsDF.iloc[index[1]]['TEAM'],testDetailsDF.iloc[index[1]]['SPLIT DETAILS'][0][0]),
          datetime.date(2024, 2, 22),1)

# %%
index = [20,21]
plotTrees(scoringDF,
          (testDetailsDF.iloc[index[0]]['TEAM'],testDetailsDF.iloc[index[0]]['SPLIT DETAILS'][0][0]),
          (testDetailsDF.iloc[index[1]]['TEAM'],testDetailsDF.iloc[index[1]]['SPLIT DETAILS'][0][0]),
          datetime.date(2024, 2, 22),1)

# %%
index = [22,23]
plotTrees(scoringDF,
          (testDetailsDF.iloc[index[0]]['TEAM'],testDetailsDF.iloc[index[0]]['SPLIT DETAILS'][0][0]),
          (testDetailsDF.iloc[index[1]]['TEAM'],testDetailsDF.iloc[index[1]]['SPLIT DETAILS'][0][0]),
          datetime.date(2024, 2, 22),1)

# %%
# team = 'MEM'
# fature = '2FGAL5MA'
# plotTree(traditionalDF,team,feature,datetime.date(2024,2,23),1)
# plotTree(traditionalDF,team,feature,datetime.date(2024,4,15),1)
i = 14
print(testDetailsDF.iloc[i]['TEAM'])
#print(testDetailsDF.iloc[i]['SPLIT DETAILS'][0][0])
print(testDetailsDF.iloc[i]['SPLIT DETAILS'][0][0])
print(getFeatureDefintion(testDetailsDF.iloc[i]['SPLIT DETAILS'][0][0]))
# Out:
# LAC
# 2FGM %UASTL5MA
# Percent of 2 Point Field Goals Made Unassisted: The percentage of 2 point field goals made by a player or team that are not assisted by a teammate

# %%
# team = 'MEM'
# fature = '2FGAL5MA'
# plotTree(traditionalDF,team,feature,datetime.date(2024,2,23),1)
# plotTree(traditionalDF,team,feature,datetime.date(2024,4,15),1)
i = 14
print(testDetailsDF.iloc[i]['TEAM'])
#print(testDetailsDF.iloc[i]['SPLIT DETAILS'][0][0])
print(testDetailsDF.iloc[i]['SPLIT DETAILS'][0][0])
print(getFeatureDefintion(testDetailsDF.iloc[i]['SPLIT DETAILS'][0][0]))
# Out:
# LAC
# 2FGM %UASTL5MA
# Percent of 2 Point Field Goals Made Unassisted: The percentage of 2 point field goals made by a player or team that are not assisted by a teammate

# %%
# team = 'MEM'
# fature = '2FGAL5MA'
# plotTree(traditionalDF,team,feature,datetime.date(2024,2,23),1)
# plotTree(traditionalDF,team,feature,datetime.date(2024,4,15),1)
i = 14
print(testDetailsDF.iloc[i]['TEAM'])
#print(testDetailsDF.iloc[i]['SPLIT DETAILS'][0][0])
print(testDetailsDF.iloc[i]['SPLIT DETAILS'][0][0])
print(getFeatureDefintion(testDetailsDF.iloc[i]['SPLIT DETAILS'][0][0]))
# Out:
# LAC
# 2FGM %UASTL5MA
# Percent of 2 Point Field Goals Made Unassisted: The percentage of 2 point field goals made by a player or team that are not assisted by a teammate

# %%
# team = 'MEM'
# fature = '2FGAL5MA'
# plotTree(traditionalDF,team,feature,datetime.date(2024,2,23),1)
# plotTree(traditionalDF,team,feature,datetime.date(2024,4,15),1)
i = 14
print(testDetailsDF.iloc[i]['TEAM'])
#print(testDetailsDF.iloc[i]['SPLIT DETAILS'][0][0])
print(testDetailsDF.iloc[i]['SPLIT DETAILS'][0][0])
print(getFeatureDefintion(testDetailsDF.iloc[i]['SPLIT DETAILS'][0][0]))
# Out:
# LAC
# 2FGM %UASTL5MA
# Percent of 2 Point Field Goals Made Unassisted: The percentage of 2 point field goals made by a player or team that are not assisted by a teammate

# %%
# team = 'MEM'
# fature = '2FGAL5MA'
# plotTree(traditionalDF,team,feature,datetime.date(2024,2,23),1)
# plotTree(traditionalDF,team,feature,datetime.date(2024,4,15),1)
i = 14
print(testDetailsDF.iloc[i]['TEAM'])
#print(testDetailsDF.iloc[i]['SPLIT DETAILS'][0][0])
print(testDetailsDF.iloc[i]['SPLIT DETAILS'][0][0])
print(getFeatureDefintion(testDetailsDF.iloc[i]['SPLIT DETAILS'][0][0]))
# Out:
# LAC
# 2FGM %UASTL5MA
# Percent of 2 Point Field Goals Made Unassisted: The percentage of 2 point field goals made by a player or team that are not assisted by a teammate

# %%
# team = 'MEM'
# fature = '2FGAL5MA'
# plotTree(traditionalDF,team,feature,datetime.date(2024,2,23),1)
# plotTree(traditionalDF,team,feature,datetime.date(2024,4,15),1)
i = 14
print(testDetailsDF.iloc[i]['TEAM'])
#print(testDetailsDF.iloc[i]['SPLIT DETAILS'][0][0])
print(testDetailsDF.iloc[i]['SPLIT DETAILS'][0][0])
print(getFeatureDefintion(testDetailsDF.iloc[i]['SPLIT DETAILS'][0][0]))
# Out:
# LAC
# 2FGM %UASTL5MA
# Percent of 2 Point Field Goals Made Unassisted: The percentage of 2 point field goals made by a player or team that are not assisted by a teammate

# %%
# team = 'MEM'
# fature = '2FGAL5MA'
# plotTree(traditionalDF,team,feature,datetime.date(2024,2,23),1)
# plotTree(traditionalDF,team,feature,datetime.date(2024,4,15),1)
i = 14
print(testDetailsDF.iloc[i]['TEAM'])
#print(testDetailsDF.iloc[i]['SPLIT DETAILS'][0][0])
print(testDetailsDF.iloc[i]['SPLIT DETAILS'][0][0])
print(getFeatureDefintion(testDetailsDF.iloc[i]['SPLIT DETAILS'][0][0]))
# Out:
# LAC
# 2FGM %UASTL5MA
# Percent of 2 Point Field Goals Made Unassisted: The percentage of 2 point field goals made by a player or team that are not assisted by a teammate

# %%
# team = 'MEM'
# fature = '2FGAL5MA'
# plotTree(traditionalDF,team,feature,datetime.date(2024,2,23),1)
# plotTree(traditionalDF,team,feature,datetime.date(2024,4,15),1)
i = 14
print(testDetailsDF.iloc[i]['TEAM'])
#print(testDetailsDF.iloc[i]['SPLIT DETAILS'][0][0])
print(testDetailsDF.iloc[i]['SPLIT DETAILS'][0][0])
print(getFeatureDefintion(testDetailsDF.iloc[i]['SPLIT DETAILS'][0][0]))
# Out:
# LAC
# 2FGM %UASTL5MA
# Percent of 2 Point Field Goals Made Unassisted: The percentage of 2 point field goals made by a player or team that are not assisted by a teammate

# %%
# team = 'MEM'
# fature = '2FGAL5MA'
# plotTree(traditionalDF,team,feature,datetime.date(2024,2,23),1)
# plotTree(traditionalDF,team,feature,datetime.date(2024,4,15),1)
i = 23
print(testDetailsDF.iloc[i]['TEAM'])
#print(testDetailsDF.iloc[i]['SPLIT DETAILS'][0][0])
print(testDetailsDF.iloc[i]['SPLIT DETAILS'][0][0])
print(getFeatureDefintion(testDetailsDF.iloc[i]['SPLIT DETAILS'][0][0]))
# Out:
# SAC
# 3FGM %ASTL5MA
# 3 Pointers Made (Percent Assisted): The percentage of 3 point field goals made that are assisted by a teammate

# %%
plotTrees(scoringDF,
          (testDetailsDF.iloc[22]['TEAM'],testDetailsDF.iloc[22]['SPLIT DETAILS'][0][0]),
          (testDetailsDF.iloc[23]['TEAM'],testDetailsDF.iloc[23]['SPLIT DETAILS'][0][0]),
          datetime.date(2024, 2, 22),1)

# %%
plotTrees(scoringDF,
          (testDetailsDF.iloc[22]['TEAM'],testDetailsDF.iloc[22]['SPLIT DETAILS'][0][0]),
          (testDetailsDF.iloc[23]['TEAM'],testDetailsDF.iloc[23]['SPLIT DETAILS'][0][0]),
          datetime.date(2024, 2, 22),1)

# %%
plotTrees(scoringDF,
          (testDetailsDF.iloc[22]['TEAM'],testDetailsDF.iloc[22]['SPLIT DETAILS'][0][0]),
          (testDetailsDF.iloc[23]['TEAM'],testDetailsDF.iloc[23]['SPLIT DETAILS'][0][0]),
          datetime.date(2024, 2, 22),1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '%PTS OFF TOL3MA'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-79-fd902043ac9c> in <module>
# ----> 1 plotTrees(traditionalDF,
#       2           (testDetailsDF.iloc[2]['TEAM'],testDetailsDF.iloc[2]['SPLIT DETAILS'][0][0]),
#       3           (testDetailsDF.iloc[3]['TEAM'],testDetailsDF.iloc[3]['SPLIT DETAILS'][0][0]),
#       4           datetime.date(2024, 2, 22),1)
#
# <ipython-input-75-46de5589b5de> in plotTrees(NBAdf, awayTeam, homeTeam, date, maxDepth)
#      38             features.append(tuple_[featureIter])
#      39         X_trainDF = pd.DataFrame()
# ---> 40         for feature in features: X_trainDF = pd.concat([X_trainDF,NBAtrain[NBAtrain['TEAM'] == team][feature]],axis=1)
#      41         y_trainDF = NBAtrain[NBAtrain['TEAM'] == team]['RESULT']
#      42         model = DecisionTreeClassifier(random_state=0,max_depth=maxDepth)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: '%PTS OFF TOL3MA'

# %%
plotTrees(traditionalDF,
          (testDetailsDF.iloc[4]['TEAM'],testDetailsDF.iloc[4]['SPLIT DETAILS'][0][0]),
          (testDetailsDF.iloc[5]['TEAM'],testDetailsDF.iloc[5]['SPLIT DETAILS'][0][0]),
          datetime.date(2024, 2, 22),1)

# %%
plotTrees(traditionalDF,
          (testDetailsDF.iloc[6]['TEAM'],testDetailsDF.iloc[6]['SPLIT DETAILS'][0][0]),
          (testDetailsDF.iloc[7]['TEAM'],testDetailsDF.iloc[7]['SPLIT DETAILS'][0][0]),
          datetime.date(2024, 2, 22),1)

# %%
plotTrees(traditionalDF,
          (testDetailsDF.iloc[8]['TEAM'],testDetailsDF.iloc[8]['SPLIT DETAILS'][0][0]),
          (testDetailsDF.iloc[9]['TEAM'],testDetailsDF.iloc[9]['SPLIT DETAILS'][0][0]),
          datetime.date(2024, 2, 22),1)

# %%
plotTrees(traditionalDF,
          (testDetailsDF.iloc[10]['TEAM'],testDetailsDF.iloc[10]['SPLIT DETAILS'][0][0]),
          (testDetailsDF.iloc[11]['TEAM'],testDetailsDF.iloc[11]['SPLIT DETAILS'][0][0]),
          datetime.date(2024, 2, 22),1)

# %%
plotTrees(traditionalDF,
          (testDetailsDF.iloc[12]['TEAM'],testDetailsDF.iloc[12]['SPLIT DETAILS'][0][0]),
          (testDetailsDF.iloc[13]['TEAM'],testDetailsDF.iloc[13]['SPLIT DETAILS'][0][0]),
          datetime.date(2024, 2, 22),1)

# %%
plotTrees(traditionalDF,
          (testDetailsDF.iloc[14]['TEAM'],testDetailsDF.iloc[14]['SPLIT DETAILS'][0][0]),
          (testDetailsDF.iloc[15]['TEAM'],testDetailsDF.iloc[15]['SPLIT DETAILS'][0][0]),
          datetime.date(2024, 2, 22),1)

# %%
plotTrees(traditionalDF,
          (testDetailsDF.iloc[16]['TEAM'],testDetailsDF.iloc[16]['SPLIT DETAILS'][0][0]),
          (testDetailsDF.iloc[17]['TEAM'],testDetailsDF.iloc[17]['SPLIT DETAILS'][0][0]),
          datetime.date(2024, 2, 22),1)

# %%
plotTrees(traditionalDF,
          (testDetailsDF.iloc[18]['TEAM'],testDetailsDF.iloc[18]['SPLIT DETAILS'][0][0]),
          (testDetailsDF.iloc[19]['TEAM'],testDetailsDF.iloc[19]['SPLIT DETAILS'][0][0]),
          datetime.date(2024, 2, 22),1)

# %%
plotTrees(traditionalDF,
          (testDetailsDF.iloc[20]['TEAM'],testDetailsDF.iloc[20]['SPLIT DETAILS'][0][0]),
          (testDetailsDF.iloc[21]['TEAM'],testDetailsDF.iloc[21]['SPLIT DETAILS'][0][0]),
          datetime.date(2024, 2, 22),1)

# %%
plotTrees(traditionalDF,
          (testDetailsDF.iloc[22]['TEAM'],testDetailsDF.iloc[22]['SPLIT DETAILS'][0][0]),
          (testDetailsDF.iloc[23]['TEAM'],testDetailsDF.iloc[23]['SPLIT DETAILS'][0][0]),
          datetime.date(2024, 2, 22),1)

# %%
team = 'ORL'
teamDF = traditionalDF[traditionalDF['TEAM'] == team]
teamDF = teamDF[teamDF['DATE'] > datetime.date(2024, 2, 22)]
#teamDF =

# %%
#https://www.youtube.com/@ahmaddawood_deeplearners
#https://www.youtube.com/watch?v=v6VJ2RO66Ag

# %%
# for date in dates:
#     plotTree(scoringDF,'ORL',scoringFeatures,date,1)

# %%
# for date in dates:
#     plotTree(traditionalDF,'ORL',traditionalFeatures,date,1)

# %%
# for date in dates:
#     plotTree(advancedDF,'ORL',advancedFeatures,date,1)

# %%
# for date in dates:
#     plotTree(miscDF,'ORL',miscFeatures,date,1)

# %%
# team = 'ORL'
# feature = 'FGM %UASTL3MA'
# teamDF = teamDF[teamDF['DATE'] < datetime.date(2024, 2, 22)]
# teamDF = teamDF.reset_index(drop=True)
# teamDF = teamDF.dropna()
# print('LHS:',len(teamDF[teamDF[feature] <= 43.133]))
# print('LHS:',sum(teamDF[teamDF[feature] <= 43.133]['RESULT'] == 0))
# print('LHS:',sum(teamDF[teamDF[feature] <= 43.133]['RESULT'] == 1))
# print('RHS:',len(teamDF[teamDF[feature] > 43.133]))
# print('RHS:',sum(teamDF[teamDF[feature] > 43.133]['RESULT'] == 0))
# print('RHS:',sum(teamDF[teamDF[feature] > 43.133]['RESULT'] == 1))
# print()
# team = 'ORL'
# feature = '%PTS FBPSL5MA'
# teamDF = scoringDF[scoringDF['TEAM'] == team]
# teamDF = teamDF[teamDF['DATE'] < datetime.date(2024, 2, 22)]
# teamDF = teamDF.reset_index(drop=True)
# teamDF = teamDF.dropna()
# print('LHS:',len(teamDF[teamDF[feature] <= 11.12]))
# print('LHS:',sum(teamDF[teamDF[feature] <= 11.12]['RESULT'] == 0))
# print('LHS:',sum(teamDF[teamDF[feature] <= 11.12]['RESULT'] == 1))
# print('RHS:',len(teamDF[teamDF[feature] > 11.12]))
# print('RHS:',sum(teamDF[teamDF[feature] > 11.12]['RESULT'] == 0))
# print('RHS:',sum(teamDF[teamDF[feature] > 11.12]['RESULT'] == 1))

# %%
# team = 'ORL'
# teamDF = scoringDF[scoringDF['TEAM'] == team]
# teamDF

# %%
# plotTree(scoringDF,'ORL',scoringFeatures,datetime.date(2024,3,21),1)

# %%
WGI

# %%
WGI = getDepth1Split(scoringDF,scoringFeatures,'ORL',datetime.date(2024,2,22))
WGIdf = pd.DataFrame()
for i in range(len(WGI)):
    WGIdf = WGIdf.append(pd.DataFrame(WGI[i]).T.drop(index=[0]).rename(columns={0:'INDEX_',1:'DATE',
                                                                                2:'TEAM',3:'FEATURE',
                                                                                4:'SPLIT OPTION',5:'ROOT GINI',
                                                                                6:'ROOT SAMPLES',7:'LHS',
                                                                                8:'RHS',9:'LHS GINI',
                                                                                10:'RHS GINI',11:'WGI'}))
WGIdf = WGIdf.drop(columns=['INDEX_'])
WGIdf = WGIdf.reset_index(drop=True)
WGIdf.sort_values(by='WGI').reset_index(drop=True)

# %%
WGI = getDepth1Split(scoringDF,scoringFeatures,'CLE',datetime.date(2024,2,22))
WGIdf = pd.DataFrame()
for i in range(len(WGI)):
    WGIdf = WGIdf.append(pd.DataFrame(WGI[i]).T.drop(index=[0]).rename(columns={0:'INDEX_',1:'DATE',
                                                                                2:'TEAM',3:'FEATURE',
                                                                                4:'SPLIT OPTION',5:'ROOT GINI',
                                                                                6:'ROOT SAMPLES',7:'LHS',
                                                                                8:'RHS',9:'LHS GINI',
                                                                                10:'RHS GINI',11:'WGI'}))
WGIdf = WGIdf.drop(columns=['INDEX_'])
WGIdf = WGIdf.reset_index(drop=True)
WGIdf.sort_values(by='WGI').reset_index(drop=True)

# %%
NBATeams =['ATL','BKN','BOS','CHA','CHI','CLE','DAL','DEN','DET','GSW','HOU','IND',
           'LAC','LAL','MEM','MIA','MIL','MIN','NOP','NYK','OKC','ORL','PHI','PHX',
           'POR','SAC','SAS','TOR','UTA','WAS']
traditionalTestDetailsDF = pd.DataFrame()
for key in traditionalTestDetails.keys():
    traditionalTestDetailsDF = pd.concat([traditionalTestDetailsDF,
              pd.DataFrame(traditionalTestDetails[key]).T],axis=0)
traditionalTestDetailsDF = traditionalTestDetailsDF.reset_index(drop=False)
traditionalTestDetailsDF = traditionalTestDetailsDF.rename(columns={'index':'TEAM'})

# %%
leagueFeaturesDF = pd.DataFrame()
features = {}
for team in NBATeams:
    features[team] = []
for team in NBATeams:
    teamDF = traditionalTestDetailsDF[traditionalTestDetailsDF['TEAM'] == team]
    teamDF = teamDF.reset_index(drop=True)
    for i in range(len(teamDF)):
        features[team].append(teamDF.iloc[i]['SPLIT DETAILS'][0][0])
    featureCountDF = pd.DataFrame(np.unique(pd.DataFrame(features[team]),return_counts=True)).T.rename(columns={0:'FEATURE',1:'COUNT'}).sort_values(by='COUNT',ascending=False)
    featureCountDF.insert(0,'TEAM',np.full(len(featureCountDF),team)) #reindex?
    leagueFeaturesDF = leagueFeaturesDF.append(featureCountDF)

# %%
featureCountDF

# %%
leagueFeaturesDF = leagueFeaturesDF.reset_index(drop=True)
leagueFeaturesDF

# %%
total = []
for team in leagueFeaturesDF['TEAM']:
    teamDF = leagueFeaturesDF[leagueFeaturesDF['TEAM'] == team]
    total.append(np.sum(teamDF['COUNT'].values))
leagueFeaturesDF['TOTAL'] = total
leagueFeaturesDF

# %%
maxFeatureDF = pd.DataFrame()
total = []
defintions = []
string_ = []
for team in np.unique(miscDF['TEAM']):
    teamDF = leagueFeaturesDF[leagueFeaturesDF['TEAM'] == team]
    total.append(np.sum(teamDF['COUNT'].values))
    
    maxFeatureDF = pd.concat([maxFeatureDF,teamDF.head(1)],axis=0)
    maxFeatureDF = maxFeatureDF.reset_index(drop=True)
    defintions.append(getFeatureDefintion(teamDF['FEATURE'].values[0]))
    string_.append(str(teamDF['COUNT'].values[0]) +'/'+str(total[-1]))

maxFeatureDF['FREQUENCY'] = string_
maxFeatureDF['FEATURE DEFINTION'] =  defintions
#maxFeatureDF = maxFeatureDF.rename(columns={'FEATURE':'MAX FEATURE'})
maxFeatureDF = maxFeatureDF.drop(columns='COUNT')
maxFeatureDF = maxFeatureDF.drop(columns='TOTAL')
maxFeatureDF = maxFeatureDF.reset_index(drop=True)
maxFeatureDF

# %%
total = []
maxFeature = []
maxFeatureCount = []
for team in NBATeams:
    teamDF = leagueFeaturesDF[leagueFeaturesDF['TEAM'] == team]
    maxFeature.append(teamDF.head(1)['FEATURE'].values)
    maxFeatureCount.append(teamDF.head(1)['COUNT'].values)
    total.append(np.sum(teamDF['COUNT'].values))

leagueFeaturesDF = pd.concat([pd.DataFrame(NBATeams,columns=['TEAM']),
                              pd.DataFrame(maxFeature,columns=['MAX FEATURE']),
                              pd.DataFrame(maxFeatureCount,columns=['COUNT']),
                              pd.DataFrame(total,columns=['TOTAL'])],
                             
                             axis=1)
leagueFeaturesDF

# %%
# sameFeatureDF = pd.DataFrame()
# for i in range(len(leagueFeaturesDF)):
#     if leagueFeaturesDF.iloc[i]['COUNT'] == leagueFeaturesDF.iloc[i]['TOTAL']:
#         sameFeatureDF = pd.concat([sameFeatureDF,
#                       leagueFeaturesDF.iloc[i].to_frame().T],axis=0)
# sameFeatureDF = sameFeatureDF.reset_index(drop=True)
# sameFeatureDF

# %%
# traditionalTestDetailsDF = pd.DataFrame()
# for key in traditionalTestDetails.keys():
#     traditionalTestDetailsDF = pd.concat([traditionalTestDetailsDF,
#               pd.DataFrame(traditionalTestDetails[key]).T],axis=0)
# traditionalTestDetailsDF = traditionalTestDetailsDF.reset_index(drop=False)
# traditionalTestDetailsDF = traditionalTestDetailsDF.rename(columns={'index':'TEAM'})

# %%
traditionalTestDetailsDF[traditionalTestDetailsDF['TEAM'] == 'MEM']

# %%
team = 'MEM'
fature = '2FGAL5MA'
plotTree(traditionalDF,team,feature,datetime.date(2024,2,23),1)
plotTree(traditionalDF,team,feature,datetime.date(2024,4,14),1)

# %%
# teamDF
# sum(teamDF[teamDF[feature] <= splitOption]['RESULT'] == 1)

# %%
team = 'MEM'
feature = '2FGAL5MA'
splitOption = 45.6
teamDF = traditionalDF[traditionalDF['TEAM'] == team]
results = {}
for team in NBATeams:
    results[team] = {'W':int,'L':int}
for team in NBATeams:
    teamDF = traditionalDF[traditionalDF['TEAM'] == team]
    results[team]['W'] = sum(teamDF[teamDF[feature] <= splitOption]['RESULT'] == 1)
    results[team]['L'] = sum(teamDF[teamDF[feature] <= splitOption]['RESULT'] == 0)
df = pd.DataFrame(results).T
df['W%'] = round((df['W']/(df['W']+ df['L'])) * 100,1)

df.sort_values(by='W%',ascending=False)
df = df.reset_index()
df = df.rename(columns={'index':'TEAM'})
df.sort_values(by='W%',ascending=False).reset_index(drop=True)

# %%
team = 'MEM'
feature = '2FGAL5MA'
splitOption = 45.6
teamDF = traditionalDF[traditionalDF['TEAM'] == team]
results = {}
for team in NBATeams:
    results[team] = {'W':int,'L':int}
for team in NBATeams:
    teamDF = traditionalDF[traditionalDF['TEAM'] == team]
    results[team]['W'] = sum(teamDF[teamDF[feature] <= splitOption]['RESULT'] == 1)
    results[team]['L'] = sum(teamDF[teamDF[feature] <= splitOption]['RESULT'] == 0)
df = pd.DataFrame(results).T
fStrings = []
for i in range(len(df)):
    if df.iloc[i]['W']+df.iloc[i]['L'] > 0:
        value = df.iloc[i]['W']/(df.iloc[i]['W']+df.iloc[i]['L'])
        fString =  f'{value:.1%}'
        fStrings.append(fString)
    else: fStrings.append(np.nan)
df['tempW%'] = round((df['W']/(df['W']+ df['L'])) * 100,1)
df['W%'] = fStrings
df = df.sort_values(by='tempW%',ascending=False)
df = df.drop(columns='tempW%')
df = df.reset_index()
df = df.rename(columns={'index':'TEAM'})
df

# %%
# teamDF = traditionalDF[traditionalDF['TEAM'] == 'MEM']
# print(sum(teamDF[teamDF['2FGAL5MA'] <= 45.6]['RESULT'] == 1),'-',
#       sum(teamDF[teamDF['2FGAL5MA'] <= 45.6]['RESULT'] == 0))
# print()
# for team in NBATeams:
#     teamDF = traditionalDF[traditionalDF['TEAM'] == team]
#     print(team,
#           sum(teamDF[teamDF['2FGAL5MA'] <= 45.6]['RESULT'] == 1),
#           '-',
#           sum(teamDF[teamDF['2FGAL5MA'] <= 45.6]['RESULT'] == 0))

# %%
traditionalTestDetailsDF[traditionalTestDetailsDF['TEAM'] == 'OKC']

# %%
team = 'OKC'
feature = 'REBL4MA'
plotTree(traditionalDF,team,feature,datetime.date(2024,2,22),1)
plotTree(traditionalDF,team,feature,datetime.date(2024,4,14),1)

# %%
team = 'OKC'
feature = 'REBL4MA'
splitOption = 41.875
teamDF = traditionalDF[traditionalDF['TEAM'] == team]
results = {}
for team in NBATeams:
    results[team] = {'W':int,'L':int}
for team in NBATeams:
    teamDF = traditionalDF[traditionalDF['TEAM'] == team]
    results[team]['W'] = sum(teamDF[teamDF[feature] <= splitOption]['RESULT'] == 1)
    results[team]['L'] = sum(teamDF[teamDF[feature] <= splitOption]['RESULT'] == 0)
df = pd.DataFrame(results).T
fStrings = []
for i in range(len(df)):
    if df.iloc[i]['W']+df.iloc[i]['L'] > 0:
        value = df.iloc[i]['W']/(df.iloc[i]['W']+df.iloc[i]['L'])
        fString =  f'{value:.1%}'
        fStrings.append(fString)
    else: fStrings.append(np.nan)
df['tempW%'] = round((df['W']/(df['W']+ df['L'])) * 100,1)
df['W%'] = fStrings
df = df.sort_values(by='tempW%',ascending=False)
df = df.drop(columns='tempW%')
df = df.reset_index()
df = df.rename(columns={'index':'TEAM'})
df

# %%
# team = 'OKC'
# feature = 'REBL4MA'
# splitOption = 41.875
# teamDF = traditionalDF[traditionalDF['TEAM'] == team]
# results = {}
# for team in NBATeams:
#     results[team] = {'Ws':int,'Ls':int,'W%':float}
# for team in NBATeams:
#     teamDF = traditionalDF[traditionalDF['TEAM'] == team]
#     results[team]['Ws'] = sum(teamDF[teamDF[feature] <= splitOption]['RESULT'] == 1)
#     results[team]['Ls'] = sum(teamDF[teamDF[feature] <= splitOption]['RESULT'] == 0)
#     results[team]['W%'] = results[team]['Ws'] / (results[team]['Ws']+results[team]['Ls'])*(100)
# pd.DataFrame(results).T.sort_values(by='W%',ascending=False)

# %%
traditionalTestDetailsDF[traditionalTestDetailsDF['TEAM'] == 'ORL']

# %%
team = 'ORL'
feature = 'STLL2MA'
plotTree(traditionalDF,team,feature,datetime.date(2024,2,22),1)
plotTree(traditionalDF,team,feature,datetime.date(2024,4,14),1)

# %%
team = 'ORL'
feature = 'STLL2MA'
splitOption = 6.25
teamDF = traditionalDF[traditionalDF['TEAM'] == team]
results = {}
for team in NBATeams:
    results[team] = {'W':int,'L':int}
for team in NBATeams:
    teamDF = traditionalDF[traditionalDF['TEAM'] == team]
    results[team]['W'] = sum(teamDF[teamDF[feature] <= splitOption]['RESULT'] == 1)
    results[team]['L'] = sum(teamDF[teamDF[feature] <= splitOption]['RESULT'] == 0)
df = pd.DataFrame(results).T
fStrings = []
for i in range(len(df)):
    if df.iloc[i]['W']+df.iloc[i]['L'] > 0:
        value = df.iloc[i]['W']/(df.iloc[i]['W']+df.iloc[i]['L'])
        fString =  f'{value:.1%}'
        fStrings.append(fString)
    else: fStrings.append(np.nan)
df['tempW%'] = round((df['W']/(df['W']+ df['L'])) * 100,1)
df['W%'] = fStrings
df = df.sort_values(by='tempW%',ascending=False)
df = df.drop(columns='tempW%')
df = df.reset_index()
df = df.rename(columns={'index':'TEAM'})
df

# %%
f'{1:.1%}'

# %%
#pd.concat(getModelPredictions(traditionalMatchResults))

# %%
NBATeams =['ATL','BKN','BOS','CHA','CHI','CLE','DAL','DEN','DET','GSW','HOU','IND','LAC','LAL','MEM',
           'MIA','MIL','MIN','NOP','NYK','OKC','ORL','PHI','PHX','POR','SAC','SAS','TOR','UTA','WAS']

# %%
# def getActualWinnerAccuracyByTeam(predictionsDF):
#     predictionsByTeam = {}
#     for team in np.unique(NBATeams): predictionsByTeam[team] = {}
#     for team in np.unique(NBATeams):
#         predictionsByTeam[team]['✅'] = int(len(predictionsDF[predictionsDF['ACTUAL WINNER'] == (team,'✅')]))
#         predictionsByTeam[team]['❌'] = int(len(predictionsDF[predictionsDF['ACTUAL WINNER'] == (team,'❌')]))
#     predictionsByTeamDF = pd.DataFrame(predictionsByTeam).T
#     predictionsByTeamDF['MODEL VS ACTUAL%'] = predictionsByTeamDF['✅'] / (predictionsByTeamDF['✅']+predictionsByTeamDF['❌'])
#     return predictionsByTeamDF

def getActualWinnerAccuracyByTeam(predictionsDF):
    predictionsByTeam = {}
    for team in np.unique(NBATeams): predictionsByTeam[team] = {}
    for team in np.unique(NBATeams):
        predictionsByTeam[team]['✅'] = int(len(predictionsDF[predictionsDF['ACTUAL WINNER'] == (team,'✅')]))
        predictionsByTeam[team]['❌'] = len(predictionsDF[predictionsDF['MODEL PREDICTS'] == team]) - int(len(predictionsDF[predictionsDF['ACTUAL WINNER'] == (team,'✅')]))
    predictionsByTeamDF = pd.DataFrame(predictionsByTeam).T
    predictionsByTeamDF['MODEL VS ACTUAL%'] = predictionsByTeamDF['✅'] / (predictionsByTeamDF['✅']+predictionsByTeamDF['❌'])
    return predictionsByTeamDF

def getBettingFavoriteAccuracyByTeam(predictionsDF):
    predictionsByTeam = {}
    for team in np.unique(NBATeams): predictionsByTeam[team] = {'✅':0,'❌':0}
    for i in range (len(predictionsDF)):
        if predictionsDF.iloc[i]['MODEL PREDICTS'] != ' ' and predictionsDF.iloc[i]['MODEL PREDICTS'] != 'EQUAL P1s':
            if predictionsDF.iloc[i]['MODEL PREDICTS'] == predictionsDF.iloc[i]['BETTING FAVORITE'][0]:
                predictionsByTeam[predictionsDF.iloc[i]['MODEL PREDICTS']]['✅'] = predictionsByTeam[predictionsDF.iloc[i]['MODEL PREDICTS']]['✅']+1
            else: predictionsByTeam[predictionsDF.iloc[i]['MODEL PREDICTS']]['❌'] = predictionsByTeam[predictionsDF.iloc[i]['MODEL PREDICTS']]['❌']+1
    predictionsByTeamDF = pd.DataFrame(predictionsByTeam).T
    predictionsByTeamDF['MODEL VS BETTING FAVORITE%'] = predictionsByTeamDF['✅'] / (predictionsByTeamDF['✅']+predictionsByTeamDF['❌'])
    return predictionsByTeamDF

# %%
actualWinnerAccuracyByTeam = getActualWinnerAccuracyByTeam(pd.concat(getModelPredictions(traditionalMatchResults)))
bettingFavoriteAccuracyByTeam = getBettingFavoriteAccuracyByTeam(pd.concat(getModelPredictions(traditionalMatchResults)))

# %%
pd.concat([actualWinnerAccuracyByTeam,
          bettingFavoriteAccuracyByTeam],axis=1)

# %%
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
import matplotlib.ticker as mtick 
from matplotlib.ticker import PercentFormatter 

def getImage(path, zoom=1): return OffsetImage(plt.imread(path), zoom=zoom)

paths = []
for team in NBATeams:
    paths.append('/Users/olutosinfashusi/jupyter/git/predict2023-24NBARegularSeasonGames/images/'+team+'.png')

# %%
fig, ax = plt.subplots(figsize = (27,7))
ax.get_xaxis().set_visible(False)
ymin = np.min([x for x in list(actualWinnerAccuracyByTeam['MODEL VS ACTUAL%'].values)+ list(bettingFavoriteAccuracyByTeam['MODEL VS BETTING FAVORITE%'].values) if not math.isnan(x)])
ymin = ymin - .1
ymax = np.max([x for x in list(actualWinnerAccuracyByTeam['MODEL VS ACTUAL%'].values)+ list(bettingFavoriteAccuracyByTeam['MODEL VS BETTING FAVORITE%'].values) if not math.isnan(x)])
ymax = ymax + .05
ax.set_ylim(ymin,ymax)
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1))  

plt.ylabel('% CORRECT',size=35,fontweight='bold')
plt.yticks(fontsize=25)

ax.scatter(actualWinnerAccuracyByTeam.index,actualWinnerAccuracyByTeam['MODEL VS ACTUAL%'],marker='o',c='blue',s=100);
ax.plot(actualWinnerAccuracyByTeam.index,actualWinnerAccuracyByTeam['MODEL VS ACTUAL%'],marker='o',c='blue')

ax.scatter(bettingFavoriteAccuracyByTeam.index,bettingFavoriteAccuracyByTeam['MODEL VS BETTING FAVORITE%'],marker='o',c='green',s=100);
ax.plot(bettingFavoriteAccuracyByTeam.index,bettingFavoriteAccuracyByTeam['MODEL VS BETTING FAVORITE%'],marker='o',c='green')

for x, y, path in zip(actualWinnerAccuracyByTeam.index,np.full_like(actualWinnerAccuracyByTeam.index,ymin),paths):
    ab = AnnotationBbox(getImage(path),(x,ymin), frameon=False)
    ax.add_artist(ab)
    
ymax = np.max([x for x in list(actualWinnerAccuracyByTeam['MODEL VS ACTUAL%'].values)+ list(bettingFavoriteAccuracyByTeam['MODEL VS BETTING FAVORITE%'].values) if not math.isnan(x)])
ax.annotate('Model vs Actual Result\n',(3.5,ymax),fontsize=35,fontweight ='bold',color='blue')
ax.annotate(' Model vs Betting Favorite\n',(13,ymax),fontsize=35,fontweight ='bold',color='green')
plt.grid(linestyle=':',linewidth=2)
plt.show()

# %%
fig, ax = plt.subplots(figsize = (27,7))
ax.get_xaxis().set_visible(False)
ymin = np.min([x for x in list(actualWinnerAccuracyByTeam['✅'].values)+ list(bettingFavoriteAccuracyByTeam['✅'].values) if not math.isnan(x)])
ymin = ymin - 3
ymax = np.max([x for x in list(actualWinnerAccuracyByTeam['✅'].values)+ list(bettingFavoriteAccuracyByTeam['✅'].values) if not math.isnan(x)])
ymax = ymax + .5
ax.set_ylim(ymin,ymax)

plt.ylabel('# CORRECT',size=35,fontweight='bold')
plt.yticks(fontsize=25)

ax.scatter(actualWinnerAccuracyByTeam.index,actualWinnerAccuracyByTeam['✅'],marker='o',c='blue',s=100);
ax.plot(actualWinnerAccuracyByTeam.index,actualWinnerAccuracyByTeam['✅'],marker='o',c='blue')

ax.scatter(bettingFavoriteAccuracyByTeam.index,bettingFavoriteAccuracyByTeam['✅'],marker='o',c='green',s=100);
ax.plot(bettingFavoriteAccuracyByTeam.index,bettingFavoriteAccuracyByTeam['✅'],marker='o',c='green')

for x, y, path in zip(actualWinnerAccuracyByTeam.index,np.full_like(actualWinnerAccuracyByTeam.index,ymin),paths):
    ab = AnnotationBbox(getImage(path),(x,ymin), frameon=False)
    ax.add_artist(ab)
    
ymax = np.max([x for x in list(actualWinnerAccuracyByTeam['✅'].values)+ list(bettingFavoriteAccuracyByTeam['✅'].values) if not math.isnan(x)])
ax.annotate('Model vs Actual Result\n',(3.5,ymax),fontsize=35,fontweight ='bold',color='blue')
ax.annotate(' Model vs Betting Favorite\n',(13,ymax),fontsize=35,fontweight ='bold',color='green')
plt.grid(linestyle=':',linewidth=2)
plt.show()

# %%
fig, ax = plt.subplots(figsize = (27,7))
ax.get_xaxis().set_visible(False)
ymin = np.min([x for x in list(actualWinnerAccuracyByTeam['❌'].values)+ list(bettingFavoriteAccuracyByTeam['❌'].values) if not math.isnan(x)])
ymin = ymin - 1
ymax = np.max([x for x in list(actualWinnerAccuracyByTeam['❌'].values)+ list(bettingFavoriteAccuracyByTeam['❌'].values) if not math.isnan(x)])
ymax = ymax + .5
ax.set_ylim(ymin,ymax)
plt.ylabel('# INCORRECT',size=35,fontweight='bold')
plt.yticks(fontsize=25)

ax.scatter(actualWinnerAccuracyByTeam.index,actualWinnerAccuracyByTeam['❌'],marker='o',c='blue',s=100);
ax.plot(actualWinnerAccuracyByTeam.index,actualWinnerAccuracyByTeam['❌'],marker='o',c='blue')

ax.scatter(bettingFavoriteAccuracyByTeam.index,bettingFavoriteAccuracyByTeam['❌'],marker='o',c='green',s=100);
ax.plot(bettingFavoriteAccuracyByTeam.index,bettingFavoriteAccuracyByTeam['❌'],marker='o',c='green')

for x, y, path in zip(actualWinnerAccuracyByTeam.index,np.full_like(actualWinnerAccuracyByTeam.index,ymin),paths):
    ab = AnnotationBbox(getImage(path),(x,ymin), frameon=False)
    ax.add_artist(ab)

ymax = np.max([x for x in list(actualWinnerAccuracyByTeam['❌'].values)+ list(bettingFavoriteAccuracyByTeam['❌'].values) if not math.isnan(x)])
ax.annotate('Model vs Actual Result\n',(3.5,ymax),fontsize=35,fontweight ='bold',color='blue')
ax.annotate(' Model vs Betting Favorite\n',(13,ymax),fontsize=35,fontweight ='bold',color='green')

plt.grid(linestyle=':',linewidth=2)
plt.show()
